# %%
# Provides ways to work with large multidimensional arrays
import numpy as np 
# Allows for further data manipulation and analysis
import pandas as pd
from pandas_datareader import data as web # Reads stock data 
import matplotlib.pyplot as plt # Plotting
import matplotlib.dates as mdates # Styling dates
# %matplotlib inline

import datetime as dt # For defining dates
import mplfinance as mpf # Matplotlib finance

import time

# Used to get data from a directory
import os
from os import listdir
from os.path import isfile, join

#Statsmodels is a great library we can use to run regressions.
import statsmodels.api as sm
# Seaborn extends the capabilities of Matplotlib
import seaborn as sns
# Used for calculating regressions
from statsmodels.tsa.ar_model import AutoReg, ar_select_order

# %% [markdown]
# ## Dates & Other Constants

# %%
# Define path to files
# For MacOS
#PATH = "/Users/derekbanas/Documents/Tutorials/Python for Finance/Stocks/"
# For Windows
PATH = "C:/Users/hansf/git/python/aktie/Python4Finance/Stocks/"

# Start date defaults
S_YEAR = 2017
S_MONTH = 1
S_DAY = 3
S_DATE_STR = "2017-01-03"
S_DATE_DATETIME = dt.datetime(S_YEAR, S_MONTH, S_DAY)

# End date defaults
E_YEAR = 2021
E_MONTH = 8
E_DAY = 19
E_DATE_STR = "2021-08-19"
E_DATE_DATETIME = dt.datetime(E_YEAR, E_MONTH, E_DAY)

# %% [markdown]
# ## Holds Stocks not Downloaded

# %%
stocks_not_downloaded = []
missing_stocks = []

# %% [markdown]
# ## Get Stock File Names in a List

# %%
files = [x for x in listdir(PATH) if isfile(join(PATH, x))]
tickers = [os.path.splitext(x)[0] for x in files]
tickers

# On MacOS Only
# tickers.remove('.DS_Store')
# 2886 total stocks
tickers.sort()
len(tickers)
# Out:
# 6103

# %% [markdown]
# ## Save Stock Data to CSV

# %%
# Function that gets a dataframe by providing a ticker and starting date
def save_to_csv_from_yahoo(ticker, syear, smonth, sday, eyear, emonth, eday):
    # Defines the time periods to use
    start = dt.datetime(syear, smonth, sday)
    end = dt.datetime(eyear, emonth, eday)
    
    try:
        print("Get Data for : ", ticker)
        # Reads data into a dataframe
        df = web.DataReader(ticker, 'yahoo', start, end)['Adj Close']
    
        # Wait 10 seconds
        time.sleep(5)
    
        # Save data to a CSV file Windows
        # df.to_csv('D:/Python for Finance/Update/' + ticker + '.csv')
        
        # Save data to a CSV file Mac
        df.to_csv('C:/Users/hansf/git/python/aktie/Python4Finance/Stocks' + ticker + '.csv')
    except Exception as ex:
        stocks_not_downloaded.append(ticker)
        print("Couldn't Get Data for :", ticker)

# %%
# for x in range(1501, 2886):
#   save_to_csv_from_yahoo(tickers[x], 2021, 8, 20, 2021, 9, 10)
# print("Finished")
# stocks_not_downloaded

# for x in missing_stocks:
#   save_to_csv_from_yahoo(x, 2021, 8, 20, 2021, 9, 10)
# print("Finished")
# stocks_not_downloaded

# %% [markdown]
# ## Function that Returns a Dataframe from a CSV

# %%
def get_df_from_csv(folder, ticker):
    try:
        df = pd.read_csv(folder + ticker + '.csv', index_col='Date', 
                         parse_dates=True)
    except FileNotFoundError:
        pass
        print("File Doesn't Exist")
    else:
        return df

# %% [markdown]
# ## Merge New Data

# %%
def update_stock_data(ticker):
    # For Windows 
    # up_folder = 'D:/Python for Finance/Update/'
    # For MacOS
    up_folder = 'C:/Users/hansf/git/python/aktie/Python4Finance/Update/'

    # For Windows 
    stock_folder = PATH
    # For MacOS
    #stock_folder = PATH

    update_df = get_df_from_csv(up_folder, ticker)
    update_df

    # Get original dataframe
    orig_df = get_df_from_csv(stock_folder, ticker)

    # Drop the unnamed column
    orig_df.drop(orig_df.columns[orig_df.columns.str.contains('unnamed',case = False)],
          axis = 1, inplace = True)

    # Drop the daily_return column
    orig_df = orig_df.drop('daily_return', 1)

    join_df = pd.concat([orig_df, update_df])
    return join_df

# %% [markdown]
# ## Save Dataframe to CSV

# %%
def save_dataframe_to_csv(df, folder, ticker):
    df.to_csv(folder + ticker + '.csv')

# %% [markdown]
# ## Update Files with New Data

# %%
def update_stocks(stock_folder):
    
    for x in tickers:
        try:
            print("Working on :", x)
            new_df = update_stock_data(x)
            save_dataframe_to_csv(new_df, stock_folder, x)
        except Exception as ex:
            print(ex)

# %%
# For Windows
update_stocks(PATH)
# For MacOS
#update_stocks(PATH)
# Out:
# Working on : A
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AA
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AAC
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AACG
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AACI
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on :

# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : ATOS
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : ATR
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : ATRA
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : ATRC
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : ATRI
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : ATRO
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : ATRS
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : ATSG
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : ATTO
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : ATUS
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : ATVC
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : ATVI
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : ATXI
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : ATXS
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : ATY
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AU
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AUB
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AUBN
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AUD
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AUDC
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AUGX
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AUID
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AUMN
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AUPH
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AUR
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AURA
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AURC
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AUS
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AUTL
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AUTO
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AUUD
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AUVI
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AUY
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVA
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVAC
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVAH
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVAL
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVAN
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVAV
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVB
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVCO
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVCT
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVD
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVDL
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVDX
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVEO
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVGO
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVGR
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVHI
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVID
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVIR
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVLR
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVNS
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVNT
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVNW
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVO
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVPT
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVRO
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVT
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVTE
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVTR
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVTX
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVXL
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVY
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AVYA
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AWH
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AWI
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AWK
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AWR
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AWRE
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AWX
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AX
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AXDX
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AXGN
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AXH
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AXL
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AXLA
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AXNX
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AXON
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AXP
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AXR
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AXS
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AXSM
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AXTA
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AXTI
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AXU
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AY
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AYI
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AYLA
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AYRO
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AYTU
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AYX
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AZEK
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AZN
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AZO
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AZPN
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AZRE
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AZTA
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AZUL
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AZYO
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : AZZ
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : B
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BA
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BABA
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BAC
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BACA
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BAFN
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BAH
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BAK
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BALY
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BAM
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BANC
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BAND
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BANF
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BANR
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BANX
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BAOS
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BAP
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BARK
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BASE
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BATL
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BAX
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BB
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BBAI
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BBAR
# File Doesn't Exist
# "['daily_return'] not found in axis"
# ...
# Working on : BTU
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BTWN
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BTX
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BUD
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BUR
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BURL
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BUSE
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BV
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BVH
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BVN
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BVS
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BVXV
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BW
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BWA
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BWAC
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BWAY
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BWB
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BWC
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BWEN
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BWFG
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BWMN
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BWMX
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BWXT
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BX
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BXC
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BXMT
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BXP
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BXRX
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BY
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BYD
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BYFC
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BYND
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BYRN
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BYSI
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BYTS
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BZ
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BZFD
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BZH
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : BZUN
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : C
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CAAP
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CAAS
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CABA
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CABO
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CAC
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CACC
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CACI
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CADE
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CADL
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CAE
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CAG
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CAH
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CAJ
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CAKE
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CAL
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CALA
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CALB
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CALM
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CALT
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CALX
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CAMP
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CAMT
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CAN
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CANF
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CANG
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CANO
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CAPL
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CAPR
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CAR
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CARA
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CARE
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CARG
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CARR
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CARS
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CARV
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CAS
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CASA
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CASH
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CASI
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CASS
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CASY
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CAT
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CATC
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CATO
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CATY
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CB
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CBAN
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CBAT
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CBAY
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CBD
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CBFV
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CBIO
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CBL
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CBNK
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CBOE
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CBRE
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CBRL
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CBSH
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CBT
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CBTX
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CBU
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CBZ
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CC
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CCAC
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CCAI
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CCAP
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CCB
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CCBG
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CCCC
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CCCS
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CCEL
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CCEP
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CCF
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CCI
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CCJ
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CCK
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CCL
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CCLP
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CCM
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CCMP
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CCNC
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CCNE
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CCO
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CCOI
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CCRD
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CCRN
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CCS
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CCSI
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CCU
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CCV
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CCVI
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CCXI
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CD
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CDAK
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CDAQ
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CDAY
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CDE
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CDEV
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CDK
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CDLX
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CDMO
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CDNA
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CDNS
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CDOR
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CDR
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CDRE
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CDRO
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CDTX
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CDW
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CDXC
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CDXS
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CDZI
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CE
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CEA
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CECE
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CEI
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CEIX
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CELC
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CELH
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CELP
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CELU
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CELZ
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CEMI
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CENQ
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CENT
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CENTA
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CENX
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CEPU
# File Doesn't Exist
# "['daily_return'] not found in axis"
# Working on : CEQP
# File Doesn't Exist
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_45312/3204484186.py in <module>
#       1 # For Windows
# ----> 2 update_stocks(PATH)
#       3 # For MacOS
#       4 #update_stocks(PATH)
#
# ~\AppData\Local\Temp/ipykernel_45312/1284447347.py in update_stocks(stock_folder)
#       4         try:
#       5             print("Working on :", x)
# ----> 6             new_df = update_stock_data(x)
#       7             save_dataframe_to_csv(new_df, stock_folder, x)
#       8         except Exception as ex:
#
# ~\AppData\Local\Temp/ipykernel_45312/3780132848.py in update_stock_data(ticker)
#      14
#      15     # Get original dataframe
# ---> 16     orig_df = get_df_from_csv(stock_folder, ticker)
#      17
#      18     # Drop the unnamed column
#
# ~\AppData\Local\Temp/ipykernel_45312/3154300214.py in get_df_from_csv(folder, ticker)
#       1 def get_df_from_csv(folder, ticker):
#       2     try:
# ----> 3         df = pd.read_csv(folder + ticker + '.csv', index_col='Date',
#       4                          parse_dates=True)
#       5     except FileNotFoundError:
#
# ~\miniconda3\envs\ipy_aktie_env\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\miniconda3\envs\ipy_aktie_env\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\miniconda3\envs\ipy_aktie_env\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\miniconda3\envs\ipy_aktie_env\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\miniconda3\envs\ipy_aktie_env\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\miniconda3\envs\ipy_aktie_env\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      67         kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
#      68         try:
# ---> 69             self._reader = parsers.TextReader(self.handles.handle, **kwds)
#      70         except Exception:
#      71             self.handles.close()
#
# KeyboardInterrupt:

# %% [markdown]
# ## Add Daily Return to Dataframe

# %%
# We calculate a percentage rate of return for each day to compare investments.
# Simple Rate of Return = (End Price - Beginning Price) / Beginning Price OR (EP / BP) - 1

# Shift provides the value from the previous day
# NaN is displayed because there was no previous day price for the 1st calculation
def add_daily_return_to_df(df, ticker):
    df['daily_return'] = (df['Adj Close'] / df['Adj Close'].shift(1)) - 1
    # Save data to a CSV file
    # For Windows
    df.to_csv(PATH + ticker + '.csv')
    # For MacOS
    # df.to_csv(PATH + ticker + '.csv')
    return df

# %% [markdown]
# ## Update Daily Returns

# %%
for x in tickers:
    try:
        print("Working on :", x)
        new_df = get_df_from_csv(PATH, x)
        new_df = add_daily_return_to_df(new_df, x)
        save_dataframe_to_csv(new_df, PATH, x)
    except Exception as ex:
        print(ex)

# %% [markdown]
# ## Regression Time Series Example with AutoReg

# %%
def calc_projected_roi(ticker):
    a_df = get_df_from_csv(PATH, ticker) 

    a_df = a_df.asfreq('d') # Change frequency to day
    a_df.index # Check frequency
    a_df = a_df.fillna(method='ffill') # Fill missing values

    # Delete unnamed column
    a_df.drop(a_df.columns[a_df.columns.str.contains('unnamed',case = False)],
          axis = 1, inplace = True)

    # Delete daily return column
    a_df = a_df.drop(['daily_return'], axis=1)
    
    # Figure out optimum lags which will be 1 or 2 for this data set
    lags = ar_select_order(a_df, maxlag=30)

    # Create our model using whole data set
    model = AutoReg(a_df['Adj Close'], lags.ar_lags)
    model_fit = model.fit()

    # Define training and testing area
    print("Length :",len(a_df)) # 1712 observations
    train_df = a_df.iloc[50:1369] # 80% minus 1st 50
    test_df = a_df.iloc[1369:] # Last 20%

    # Define training model for 500 days (Play with Number & Test)
    # and White's covariance estimator
    train_model = AutoReg(a_df['Adj Close'], 500).fit(cov_type="HC0")

    # Define start and end for prediction 
    start = len(train_df)
    end = len(train_df) + len(test_df) - 1

    prediction = train_model.predict(start=start, end=end, dynamic=True)

    # Predict 160 days into the future
    forecast = train_model.predict(start=end, end=end+60, dynamic=True)

    # Get starting price of prediction
    s_price = forecast.head(1).iloc[0]

    # Get the last price of prediction
    e_price = forecast.iloc[-1]

    # Get return over prediction
    return (e_price - s_price) / s_price

# %%
def get_proj_rois():
    # Will hold all tickers & stock rois
    ticker = []
    roi = []
    
    for x in tickers:
        print("Working on :", x)
        try:
            the_roi = calc_projected_roi(x)
        except Exception as ex:
            print("Stock Data Corrupted")
        else:
            ticker.append(x)
            print("ROI :", the_roi)
            roi.append(the_roi)
        
    return pd.DataFrame({'Ticker':ticker, 'ROI':roi})

# %%
proj_roi_df = get_proj_rois()
proj_roi_df

# %%
proj_roi_df.sort_values(by=['ROI'], ascending=False)[0:20]
# Out:
#      Ticker       ROI
# 494     CEI  6.670116
# 631    CPSH  5.583947
# 2783   WKHS  4.020647
# 2397   SPRT  1.921685
# 789     DSS  1.749406
# 448    CATB  1.468496
# 2165   REPH  1.466239
# 2095    PTE  1.455325
# 2049   PMTS  1.367105
# 1887    ODT  1.182327
# 42      ACY  1.121812
# 1509    LEU  1.099083
# 191    APRN  1.074054
# 1526   LIVE  1.012977
# 314    BCLI  1.011791
# 2401   SPWR  0.983358
# 1284    ICD  0.842299
# 533    CIDM  0.828471
# 128     ALT  0.798580
# 135     AMC  0.751587
