# %%
# Provides ways to work with large multidimensional arrays
import numpy as np 
# Allows for further data manipulation and analysis
import pandas as pd 
import matplotlib.pyplot as plt # Plotting
import matplotlib.dates as mdates # Styling dates
# %matplotlib inline

# pip install numpy
# conda install -c anaconda pandas
# conda install -c conda-forge matplotlib

import datetime as dt # For defining dates

import time

# In Powershell Prompt : conda install -c conda-forge multitasking
# pip install -i https://pypi.anaconda.org/ranaroussi/simple yfinance

import yfinance as yf

# To show all your output File -> Preferences -> Settings Search for Notebook
# Notebook Output Text Line Limit and set to 100

# Used for file handling like deleting files
import os

# conda install -c conda-forge cufflinks-py
# conda install -c plotly plotly
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()

from plotly.subplots import make_subplots

# New Imports
# Used to get data from a directory
import os
from os import listdir
from os.path import isfile, join

import warnings
warnings.simplefilter("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Constants

# %%
PATH = "C:/Users/hansf/git/python/aktie/Python4Finance/"

# Start end date defaults
S_DATE = "2017-02-01"
E_DATE = "2022-12-06"
S_DATE_DT = pd.to_datetime(S_DATE)
E_DATE_DT = pd.to_datetime(E_DATE)

# %% [markdown]
# ## Get Column Data from CSV

# %%
def get_column_from_csv(file, col_name):
    # Try to get the file and if it doesn't exist issue a warning
    try:
        df = pd.read_csv(file)
    except FileNotFoundError:
        print("File Doesn't Exist")
    else:
        return df[col_name]

# %% [markdown]
# ## Get Stock Tickers

# %%
tickers = get_column_from_csv("C:/Users/hansf/git/python/aktie/Python4Finance/Wilshire-5000-Stocks.csv", "Ticker")
print(len(tickers))
# Out:
# 3481

# %% [markdown]
# ## Save Stock Data to CSV

# %%
# Function that gets a dataframe by providing a ticker and starting date
def save_to_csv_from_yahoo(folder, ticker):
    stock = yf.Ticker(ticker)
    
    try:
        print("Get Data for : ", ticker)
        # Get historical closing price data
        df = stock.history(period="5y")
    
        # Wait 2 seconds
        time.sleep(2)
        
        # Remove the period for saving the file name
        # Save data to a CSV file
        # File to save to 
        the_file = folder + ticker.replace(".", "_") + '.csv'
        print(the_file, " Saved")
        df.to_csv(the_file)
    except Exception as ex:
        print("Couldn't Get Data for :", ticker)

# %% [markdown]
# ## Download All Stocks

# %%
for x in range(0, 3481):
    save_to_csv_from_yahoo(PATH, tickers[x])
    print("Finished")
# Out:
# Get Data for :  A
# C:/Users/hansf/git/python/aktie/Python4Finance/A.csv  Saved
# Finished
# Get Data for :  AA
# C:/Users/hansf/git/python/aktie/Python4Finance/AA.csv  Saved
# Finished
# Get Data for :  AAL
# C:/Users/hansf/git/python/aktie/Python4Finance/AAL.csv  Saved
# Finished
# Get Data for :  AAME
# C:/Users/hansf/git/python/aktie/Python4Finance/AAME.csv  Saved
# Finished
# Get Data for :  AAN
# C:/Users/hansf/git/python/aktie/Python4Finance/AAN.csv  Saved
# Finished
# Get Data for :  AAOI
# C:/Users/hansf/git/python/aktie/Python4Finance/AAOI.csv  Saved
# Finished
# Get Data for :  AAON
# C:/Users/hansf/git/python/aktie/Python4Finance/AAON.csv  Saved
# Finished
# Get Data for :  AAP
# C:/Users/hansf/git/python/aktie/Python4Finance/AAP.csv  Saved
# Finished
# Get Data for :  AAPL
# C:/Users/hansf/git/python/aktie/Python4Finance/AAPL.csv  Saved
# Finished
# Get Data for :  AAT
# C:/Users/hansf/git/python/aktie/Python4Finance/AAT.csv  Saved
# Finished
# Get Data for :  AAWW
# C:/Users/hansf/git/python/aktie/Python4Finance/AAWW.csv  Saved
# Finished
# Get Data for :  AAXN
# - AAXN: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/AAXN.csv  Saved
# Finished
# Get Data for :  ABBV
# C:/Users/hansf/git/python/aktie/Python4Finance/ABBV.csv  Saved
# Finished
# Get Data for :  ABC
# C:/Users/hansf/git/python/aktie/Python4Finance/ABC.csv  Saved
# Finished
# Get Data for :  ABCB
# C:/Users/hansf/git/python/aktie/Python4Finance/ABCB.csv  Saved
# Finished
# Get Data for :  ABEO
# C:/Users/hansf/git/python/aktie/Python4Finance/ABEO.csv  Saved
# Finished
# Get Data for :  ABG
# C:/Users/hansf/git/python/aktie/Python4Finance/ABG.csv  Saved
# Finished
# Get Data for :  ABIO
# C:/Users/hansf/git/python/aktie/Python4Finance/ABIO.csv  Saved
# Finished
# Get Data for :  ABM
# C:/Users/hansf/git/python/aktie/Python4Finance/ABM.csv  Saved
# Finished
# Get Data for :  ABMD
# C:/Users/hansf/git/python/aktie/Python4Finance/ABMD.csv  Saved
# Finished
# Get Data for :  ABR
# C:/Users/hansf/git/python/aktie/Python4Finance/ABR.csv  Saved
# Finished
# Get Data for :  ABT
# C:/Users/hansf/git/python/aktie/Python4Finance/ABT.csv  Saved
# Finished
# Get Data for :  ABTX
# C:/Users/hansf/git/python/aktie/Python4Finance/ABTX.csv  Saved
# Finished
# Get Data for :  AC
# C:/Users/hansf/git/python/aktie/Python4Finance/AC.csv  Saved
# Finished
# Get Data for :  ACA
# C:/Users/hansf/git/python/aktie/Python4Finance/ACA.csv  Saved
# Finished
# Get Data for :  ACAD
# C:/Users/hansf/git/python/aktie/Python4Finance/ACAD.csv  Saved
# Finished
# Get Data for :  ACBI
# C:/Users/hansf/git/python/aktie/Python4Finance/ACBI.csv  Saved
# Finished
# Get Data for :  ACC
# C:/Users/hansf/git/python/aktie/Python4Finance/ACC.csv  Saved
# Finished
# Get Data for :  ACCO
# C:/Users/hansf/git/python/aktie/Python4Finance/ACCO.csv  Saved
# Finished
# Get Data for :  ACER
# C:/Users/hansf/git/python/aktie/Python4Finance/ACER.csv  Saved
# Finished
# Get Data for :  ACGL
# C:/Users/hansf/git/python/aktie/Python4Finance/ACGL.csv  Saved
# Finished
# Get Data for :  ACHC
# C:/Users/hansf/git/python/aktie/Python4Finance/ACHC.csv  Saved
# Finished
# Get Data for :  ACHV
# C:/Users/hansf/git/python/aktie/Python4Finance/ACHV.csv  Saved
# Finished
# Get Data for :  ACIA
# - ACIA: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/ACIA.csv  Saved
# Finished
# Get Data for :  ACIW
# C:/Users/hansf/git/python/aktie/Python4Finance/ACIW.csv  Saved
# Finished
# Get Data for :  ACLS
# C:/Users/hansf/git/python/aktie/Python4Finance/ACLS.csv  Saved
# Finished
# Get Data for :  ACM
# C:/Users/hansf/git/python/aktie/Python4Finance/ACM.csv  Saved
# Finished
# Get Data for :  ACMR
# C:/Users/hansf/git/python/aktie/Python4Finance/ACMR.csv  Saved
# Finished
# Get Data for :  ACN
# C:/Users/hansf/git/python/aktie/Python4Finance/ACN.csv  Saved
# Finished
# Get Data for :  ACNB
# C:/Users/hansf/git/python/aktie/Python4Finance/ACNB.csv  Saved
# Finished
# Get Data for :  ACOR
# C:/Users/hansf/git/python/aktie/Python4Finance/ACOR.csv  Saved
# Finished
# Get Data for :  ACRE
# C:/Users/hansf/git/python/aktie/Python4Finance/ACRE.csv  Saved
# Finished
# Get Data for :  ACRS
# C:/Users/hansf/git/python/aktie/Python4Finance/ACRS.csv  Saved
# Finished
# Get Data for :  ACRX
# C:/Users/hansf/git/python/aktie/Python4Finance/ACRX.csv  Saved
# Finished
# Get Data for :  ACTG
# C:/Users/hansf/git/python/aktie/Python4Finance/ACTG.csv  Saved
# Finished
# Get Data for :  ACU
# C:/Users/hansf/git/python/aktie/Python4Finance/ACU.csv  Saved
# Finished
# Get Data for :  ACY
# C:/Users/hansf/git/python/aktie/Python4Finance/ACY.csv  Saved
# Finished
# Get Data for :  ADBE
# C:/Users/hansf/git/python/aktie/Python4Finance/ADBE.csv  Saved
# Finished
# Get Data for :  ADC
# C:/Users/hansf/git/python/aktie/Python4Finance/ADC.csv  Saved
# Finished
# Get Data for :  ADES
# C:/Users/hansf/git/python/aktie/Python4Finance/ADES.csv  Saved
# Finished
# Get Data for :  ADI
# C:/Users/hansf/git/python/aktie/Python4Finance/ADI.csv  Saved
# Finished
# Get Data for :  ADM
# C:/Users/hansf/git/python/aktie/Python4Finance/ADM.csv  Saved
# Finished
# Get Data for :  ADMA
# C:/Users/hansf/git/python/aktie/Python4Finance/ADMA.csv  Saved
# Finished
# Get Data for :  ADMP
# C:/Users/hansf/git/python/aktie/Python4Finance/ADMP.csv  Saved
# Finished
# Get Data for :  ADMS
# - ADMS: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/ADMS.csv  Saved
# Finished
# Get Data for :  ADNT
# C:/Users/hansf/git/python/aktie/Python4Finance/ADNT.csv  Saved
# Finished
# Get Data for :  ADP
# C:/Users/hansf/git/python/aktie/Python4Finance/ADP.csv  Saved
# Finished
# Get Data for :  ADRO
# - ADRO: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/ADRO.csv  Saved
# Finished
# Get Data for :  ADS
# C:/Users/hansf/git/python/aktie/Python4Finance/ADS.csv  Saved
# Finished
# Get Data for :  ADSK
# C:/Users/hansf/git/python/aktie/Python4Finance/ADSK.csv  Saved
# Finished
# Get Data for :  ADSW
# - ADSW: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/ADSW.csv  Saved
# Finished
# Get Data for :  ADT
# C:/Users/hansf/git/python/aktie/Python4Finance/ADT.csv  Saved
# Finished
# Get Data for :  ADTN
# C:/Users/hansf/git/python/aktie/Python4Finance/ADTN.csv  Saved
# Finished
# Get Data for :  ADUS
# C:/Users/hansf/git/python/aktie/Python4Finance/ADUS.csv  Saved
# Finished
# Get Data for :  ADVM
# C:/Users/hansf/git/python/aktie/Python4Finance/ADVM.csv  Saved
# Finished
# Get Data for :  ADXS
# C:/Users/hansf/git/python/aktie/Python4Finance/ADXS.csv  Saved
# Finished
# Get Data for :  AE
# C:/Users/hansf/git/python/aktie/Python4Finance/AE.csv  Saved
# Finished
# Get Data for :  AEE
# C:/Users/hansf/git/python/aktie/Python4Finance/AEE.csv  Saved
# Finished
# Get Data for :  AEGN
# - AEGN: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/AEGN.csv  Saved
# Finished
# Get Data for :  AEHR
# C:/Users/hansf/git/python/aktie/Python4Finance/AEHR.csv  Saved
# Finished
# Get Data for :  AEIS
# C:/Users/hansf/git/python/aktie/Python4Finance/AEIS.csv  Saved
# Finished
# Get Data for :  AEL
# C:/Users/hansf/git/python/aktie/Python4Finance/AEL.csv  Saved
# Finished
# Get Data for :  AEMD
# C:/Users/hansf/git/python/aktie/Python4Finance/AEMD.csv  Saved
# Finished
# Get Data for :  AEO
# C:/Users/hansf/git/python/aktie/Python4Finance/AEO.csv  Saved
# Finished
# Get Data for :  AEP
# C:/Users/hansf/git/python/aktie/Python4Finance/AEP.csv  Saved
# Finished
# Get Data for :  AERI
# C:/Users/hansf/git/python/aktie/Python4Finance/AERI.csv  Saved
# Finished
# Get Data for :  AES
# C:/Users/hansf/git/python/aktie/Python4Finance/AES.csv  Saved
# Finished
# Get Data for :  AEY
# C:/Users/hansf/git/python/aktie/Python4Finance/AEY.csv  Saved
# Finished
# Get Data for :  AFG
# C:/Users/hansf/git/python/aktie/Python4Finance/AFG.csv  Saved
# Finished
# Get Data for :  AFH
# - AFH: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/AFH.csv  Saved
# Finished
# Get Data for :  AFI
# C:/Users/hansf/git/python/aktie/Python4Finance/AFI.csv  Saved
# Finished
# Get Data for :  AFIN
# C:/Users/hansf/git/python/aktie/Python4Finance/AFIN.csv  Saved
# Finished
# Get Data for :  AFL
# C:/Users/hansf/git/python/aktie/Python4Finance/AFL.csv  Saved
# Finished
# Get Data for :  AGCO
# C:/Users/hansf/git/python/aktie/Python4Finance/AGCO.csv  Saved
# Finished
# Get Data for :  AGE
# C:/Users/hansf/git/python/aktie/Python4Finance/AGE.csv  Saved
# Finished
# Get Data for :  AGEN
# C:/Users/hansf/git/python/aktie/Python4Finance/AGEN.csv  Saved
# Finished
# Get Data for :  AGFS
# C:/Users/hansf/git/python/aktie/Python4Finance/AGFS.csv  Saved
# Finished
# Get Data for :  AGIO
# C:/Users/hansf/git/python/aktie/Python4Finance/AGIO.csv  Saved
# Finished
# Get Data for :  AGLE
# C:/Users/hansf/git/python/aktie/Python4Finance/AGLE.csv  Saved
# Finished
# Get Data for :  AGM
# C:/Users/hansf/git/python/aktie/Python4Finance/AGM.csv  Saved
# Finished
# Get Data for :  AGNC
# C:/Users/hansf/git/python/aktie/Python4Finance/AGNC.csv  Saved
# Finished
# Get Data for :  AGO
# C:/Users/hansf/git/python/aktie/Python4Finance/AGO.csv  Saved
# Finished
# Get Data for :  AGR
# C:/Users/hansf/git/python/aktie/Python4Finance/AGR.csv  Saved
# Finished
# Get Data for :  AGRX
# C:/Users/hansf/git/python/aktie/Python4Finance/AGRX.csv  Saved
# Finished
# Get Data for :  AGS
# C:/Users/hansf/git/python/aktie/Python4Finance/AGS.csv  Saved
# Finished
# Get Data for :  AGTC
# C:/Users/hansf/git/python/aktie/Python4Finance/AGTC.csv  Saved
# Finished
# Get Data for :  AGX
# C:/Users/hansf/git/python/aktie/Python4Finance/AGX.csv  Saved
# Finished
# Get Data for :  AGYS
# C:/Users/hansf/git/python/aktie/Python4Finance/AGYS.csv  Saved
# Finished
# Get Data for :  AHC
# - AHC: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/AHC.csv  Saved
# Finished
# Get Data for :  AHH
# C:/Users/hansf/git/python/aktie/Python4Finance/AHH.csv  Saved
# Finished
# Get Data for :  AHT
# C:/Users/hansf/git/python/aktie/Python4Finance/AHT.csv  Saved
# Finished
# Get Data for :  AIG
# C:/Users/hansf/git/python/aktie/Python4Finance/AIG.csv  Saved
# Finished
# Get Data for :  AIMC
# C:/Users/hansf/git/python/aktie/Python4Finance/AIMC.csv  Saved
# Finished
# Get Data for :  AIMT
# - AIMT: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/AIMT.csv  Saved
# Finished
# Get Data for :  AIN
# C:/Users/hansf/git/python/aktie/Python4Finance/AIN.csv  Saved
# Finished
# Get Data for :  AINC
# C:/Users/hansf/git/python/aktie/Python4Finance/AINC.csv  Saved
# Finished
# Get Data for :  AIR
# C:/Users/hansf/git/python/aktie/Python4Finance/AIR.csv  Saved
# Finished
# Get Data for :  AIRG
# C:/Users/hansf/git/python/aktie/Python4Finance/AIRG.csv  Saved
# Finished
# Get Data for :  AIRI
# C:/Users/hansf/git/python/aktie/Python4Finance/AIRI.csv  Saved
# Finished
# Get Data for :  AIRT
# C:/Users/hansf/git/python/aktie/Python4Finance/AIRT.csv  Saved
# Finished
# Get Data for :  AIT
# C:/Users/hansf/git/python/aktie/Python4Finance/AIT.csv  Saved
# Finished
# Get Data for :  AIV
# C:/Users/hansf/git/python/aktie/Python4Finance/AIV.csv  Saved
# Finished
# Get Data for :  AIZ
# C:/Users/hansf/git/python/aktie/Python4Finance/AIZ.csv  Saved
# Finished
# Get Data for :  AJG
# C:/Users/hansf/git/python/aktie/Python4Finance/AJG.csv  Saved
# Finished
# Get Data for :  AJRD
# C:/Users/hansf/git/python/aktie/Python4Finance/AJRD.csv  Saved
# Finished
# Get Data for :  AJX
# C:/Users/hansf/git/python/aktie/Python4Finance/AJX.csv  Saved
# Finished
# Get Data for :  AKAM
# C:/Users/hansf/git/python/aktie/Python4Finance/AKAM.csv  Saved
# Finished
# Get Data for :  AKBA
# C:/Users/hansf/git/python/aktie/Python4Finance/AKBA.csv  Saved
# Finished
# Get Data for :  AKCA
# - AKCA: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/AKCA.csv  Saved
# Finished
# Get Data for :  AKER
# - AKER: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/AKER.csv  Saved
# Finished
# Get Data for :  AKR
# C:/Users/hansf/git/python/aktie/Python4Finance/AKR.csv  Saved
# Finished
# Get Data for :  AKTS
# C:/Users/hansf/git/python/aktie/Python4Finance/AKTS.csv  Saved
# Finished
# Get Data for :  AL
# C:/Users/hansf/git/python/aktie/Python4Finance/AL.csv  Saved
# Finished
# Get Data for :  ALB
# C:/Users/hansf/git/python/aktie/Python4Finance/ALB.csv  Saved
# Finished
# Get Data for :  ALBO
# C:/Users/hansf/git/python/aktie/Python4Finance/ALBO.csv  Saved
# Finished
# Get Data for :  ALCO
# C:/Users/hansf/git/python/aktie/Python4Finance/ALCO.csv  Saved
# Finished
# Get Data for :  ALDX
# C:/Users/hansf/git/python/aktie/Python4Finance/ALDX.csv  Saved
# Finished
# Get Data for :  ALE
# C:/Users/hansf/git/python/aktie/Python4Finance/ALE.csv  Saved
# Finished
# Get Data for :  ALEC
# C:/Users/hansf/git/python/aktie/Python4Finance/ALEC.csv  Saved
# Finished
# Get Data for :  ALEX
# C:/Users/hansf/git/python/aktie/Python4Finance/ALEX.csv  Saved
# Finished
# Get Data for :  ALG
# C:/Users/hansf/git/python/aktie/Python4Finance/ALG.csv  Saved
# Finished
# Get Data for :  ALGN
# C:/Users/hansf/git/python/aktie/Python4Finance/ALGN.csv  Saved
# Finished
# Get Data for :  ALGT
# C:/Users/hansf/git/python/aktie/Python4Finance/ALGT.csv  Saved
# Finished
# Get Data for :  ALIM
# C:/Users/hansf/git/python/aktie/Python4Finance/ALIM.csv  Saved
# Finished
# Get Data for :  ALJJ
# C:/Users/hansf/git/python/aktie/Python4Finance/ALJJ.csv  Saved
# Finished
# Get Data for :  ALK
# C:/Users/hansf/git/python/aktie/Python4Finance/ALK.csv  Saved
# Finished
# Get Data for :  ALKS
# C:/Users/hansf/git/python/aktie/Python4Finance/ALKS.csv  Saved
# Finished
# Get Data for :  ALL
# C:/Users/hansf/git/python/aktie/Python4Finance/ALL.csv  Saved
# Finished
# Get Data for :  ALLE
# C:/Users/hansf/git/python/aktie/Python4Finance/ALLE.csv  Saved
# Finished
# Get Data for :  ALLK
# C:/Users/hansf/git/python/aktie/Python4Finance/ALLK.csv  Saved
# Finished
# Get Data for :  ALLO
# C:/Users/hansf/git/python/aktie/Python4Finance/ALLO.csv  Saved
# Finished
# Get Data for :  ALLY
# C:/Users/hansf/git/python/aktie/Python4Finance/ALLY.csv  Saved
# Finished
# Get Data for :  ALNA
# C:/Users/hansf/git/python/aktie/Python4Finance/ALNA.csv  Saved
# Finished
# Get Data for :  ALNY
# C:/Users/hansf/git/python/aktie/Python4Finance/ALNY.csv  Saved
# Finished
# Get Data for :  ALOT
# C:/Users/hansf/git/python/aktie/Python4Finance/ALOT.csv  Saved
# Finished
# Get Data for :  ALPN
# C:/Users/hansf/git/python/aktie/Python4Finance/ALPN.csv  Saved
# Finished
# Get Data for :  ALRM
# C:/Users/hansf/git/python/aktie/Python4Finance/ALRM.csv  Saved
# Finished
# Get Data for :  ALSK
# - ALSK: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/ALSK.csv  Saved
# Finished
# Get Data for :  ALSN
# C:/Users/hansf/git/python/aktie/Python4Finance/ALSN.csv  Saved
# Finished
# Get Data for :  ALT
# C:/Users/hansf/git/python/aktie/Python4Finance/ALT.csv  Saved
# Finished
# Get Data for :  ALTM
# C:/Users/hansf/git/python/aktie/Python4Finance/ALTM.csv  Saved
# Finished
# Get Data for :  ALTR
# C:/Users/hansf/git/python/aktie/Python4Finance/ALTR.csv  Saved
# Finished
# Get Data for :  ALV
# C:/Users/hansf/git/python/aktie/Python4Finance/ALV.csv  Saved
# Finished
# Get Data for :  ALX
# C:/Users/hansf/git/python/aktie/Python4Finance/ALX.csv  Saved
# Finished
# Get Data for :  ALXN
# - ALXN: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/ALXN.csv  Saved
# Finished
# Get Data for :  AM
# C:/Users/hansf/git/python/aktie/Python4Finance/AM.csv  Saved
# Finished
# Get Data for :  AMAG
# - AMAG: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/AMAG.csv  Saved
# Finished
# Get Data for :  AMAL
# C:/Users/hansf/git/python/aktie/Python4Finance/AMAL.csv  Saved
# Finished
# Get Data for :  AMAT
# C:/Users/hansf/git/python/aktie/Python4Finance/AMAT.csv  Saved
# Finished
# Get Data for :  AMBC
# C:/Users/hansf/git/python/aktie/Python4Finance/AMBC.csv  Saved
# Finished
# Get Data for :  AMC
# C:/Users/hansf/git/python/aktie/Python4Finance/AMC.csv  Saved
# Finished
# Get Data for :  AMCX
# C:/Users/hansf/git/python/aktie/Python4Finance/AMCX.csv  Saved
# Finished
# Get Data for :  AMD
# C:/Users/hansf/git/python/aktie/Python4Finance/AMD.csv  Saved
# Finished
# Get Data for :  AME
# C:/Users/hansf/git/python/aktie/Python4Finance/AME.csv  Saved
# Finished
# Get Data for :  AMED
# C:/Users/hansf/git/python/aktie/Python4Finance/AMED.csv  Saved
# Finished
# Get Data for :  AMG
# C:/Users/hansf/git/python/aktie/Python4Finance/AMG.csv  Saved
# Finished
# Get Data for :  AMGN
# C:/Users/hansf/git/python/aktie/Python4Finance/AMGN.csv  Saved
# Finished
# Get Data for :  AMH
# C:/Users/hansf/git/python/aktie/Python4Finance/AMH.csv  Saved
# Finished
# Get Data for :  AMKR
# C:/Users/hansf/git/python/aktie/Python4Finance/AMKR.csv  Saved
# Finished
# Get Data for :  AMN
# C:/Users/hansf/git/python/aktie/Python4Finance/AMN.csv  Saved
# Finished
# Get Data for :  AMNB
# C:/Users/hansf/git/python/aktie/Python4Finance/AMNB.csv  Saved
# Finished
# Get Data for :  AMOT
# C:/Users/hansf/git/python/aktie/Python4Finance/AMOT.csv  Saved
# Finished
# Get Data for :  AMP
# C:/Users/hansf/git/python/aktie/Python4Finance/AMP.csv  Saved
# Finished
# Get Data for :  AMPE
# C:/Users/hansf/git/python/aktie/Python4Finance/AMPE.csv  Saved
# Finished
# Get Data for :  AMPH
# C:/Users/hansf/git/python/aktie/Python4Finance/AMPH.csv  Saved
# Finished
# Get Data for :  AMRB
# - AMRB: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/AMRB.csv  Saved
# Finished
# Get Data for :  AMRC
# C:/Users/hansf/git/python/aktie/Python4Finance/AMRC.csv  Saved
# Finished
# Get Data for :  AMRK
# C:/Users/hansf/git/python/aktie/Python4Finance/AMRK.csv  Saved
# Finished
# Get Data for :  AMRS
# C:/Users/hansf/git/python/aktie/Python4Finance/AMRS.csv  Saved
# Finished
# Get Data for :  AMRX
# C:/Users/hansf/git/python/aktie/Python4Finance/AMRX.csv  Saved
# Finished
# Get Data for :  AMS
# C:/Users/hansf/git/python/aktie/Python4Finance/AMS.csv  Saved
# Finished
# Get Data for :  AMSC
# C:/Users/hansf/git/python/aktie/Python4Finance/AMSC.csv  Saved
# Finished
# Get Data for :  AMSF
# C:/Users/hansf/git/python/aktie/Python4Finance/AMSF.csv  Saved
# Finished
# Get Data for :  AMSWA
# C:/Users/hansf/git/python/aktie/Python4Finance/AMSWA.csv  Saved
# Finished
# Get Data for :  AMT
# C:/Users/hansf/git/python/aktie/Python4Finance/AMT.csv  Saved
# Finished
# Get Data for :  AMTD
# C:/Users/hansf/git/python/aktie/Python4Finance/AMTD.csv  Saved
# Finished
# Get Data for :  AMTX
# C:/Users/hansf/git/python/aktie/Python4Finance/AMTX.csv  Saved
# Finished
# Get Data for :  AMWD
# C:/Users/hansf/git/python/aktie/Python4Finance/AMWD.csv  Saved
# Finished
# Get Data for :  AMZN
# C:/Users/hansf/git/python/aktie/Python4Finance/AMZN.csv  Saved
# Finished
# Get Data for :  AN
# C:/Users/hansf/git/python/aktie/Python4Finance/AN.csv  Saved
# Finished
# Get Data for :  ANAB
# C:/Users/hansf/git/python/aktie/Python4Finance/ANAB.csv  Saved
# Finished
# Get Data for :  ANAT
# C:/Users/hansf/git/python/aktie/Python4Finance/ANAT.csv  Saved
# Finished
# Get Data for :  ANDE
# C:/Users/hansf/git/python/aktie/Python4Finance/ANDE.csv  Saved
# Finished
# Get Data for :  ANET
# C:/Users/hansf/git/python/aktie/Python4Finance/ANET.csv  Saved
# Finished
# Get Data for :  ANF
# C:/Users/hansf/git/python/aktie/Python4Finance/ANF.csv  Saved
# Finished
# Get Data for :  ANGI
# C:/Users/hansf/git/python/aktie/Python4Finance/ANGI.csv  Saved
# Finished
# Get Data for :  ANGO
# C:/Users/hansf/git/python/aktie/Python4Finance/ANGO.csv  Saved
# Finished
# Get Data for :  ANH
# - ANH: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/ANH.csv  Saved
# Finished
# Get Data for :  ANIK
# C:/Users/hansf/git/python/aktie/Python4Finance/ANIK.csv  Saved
# Finished
# Get Data for :  ANIP
# C:/Users/hansf/git/python/aktie/Python4Finance/ANIP.csv  Saved
# Finished
# Get Data for :  ANIX
# C:/Users/hansf/git/python/aktie/Python4Finance/ANIX.csv  Saved
# Finished
# Get Data for :  ANSS
# C:/Users/hansf/git/python/aktie/Python4Finance/ANSS.csv  Saved
# Finished
# Get Data for :  ANTM
# C:/Users/hansf/git/python/aktie/Python4Finance/ANTM.csv  Saved
# Finished
# Get Data for :  AON
# C:/Users/hansf/git/python/aktie/Python4Finance/AON.csv  Saved
# Finished
# Get Data for :  AOS
# C:/Users/hansf/git/python/aktie/Python4Finance/AOS.csv  Saved
# Finished
# Get Data for :  AOSL
# C:/Users/hansf/git/python/aktie/Python4Finance/AOSL.csv  Saved
# Finished
# Get Data for :  AP
# C:/Users/hansf/git/python/aktie/Python4Finance/AP.csv  Saved
# Finished
# Get Data for :  APA
# C:/Users/hansf/git/python/aktie/Python4Finance/APA.csv  Saved
# Finished
# Get Data for :  APAM
# C:/Users/hansf/git/python/aktie/Python4Finance/APAM.csv  Saved
# Finished
# Get Data for :  APD
# C:/Users/hansf/git/python/aktie/Python4Finance/APD.csv  Saved
# Finished
# Get Data for :  APDN
# C:/Users/hansf/git/python/aktie/Python4Finance/APDN.csv  Saved
# Finished
# Get Data for :  APEI
# C:/Users/hansf/git/python/aktie/Python4Finance/APEI.csv  Saved
# Finished
# Get Data for :  APEN
# C:/Users/hansf/git/python/aktie/Python4Finance/APEN.csv  Saved
# Finished
# Get Data for :  APH
# C:/Users/hansf/git/python/aktie/Python4Finance/APH.csv  Saved
# Finished
# Get Data for :  APLE
# C:/Users/hansf/git/python/aktie/Python4Finance/APLE.csv  Saved
# Finished
# Get Data for :  APLS
# C:/Users/hansf/git/python/aktie/Python4Finance/APLS.csv  Saved
# Finished
# Get Data for :  APOG
# C:/Users/hansf/git/python/aktie/Python4Finance/APOG.csv  Saved
# Finished
# Get Data for :  APPF
# C:/Users/hansf/git/python/aktie/Python4Finance/APPF.csv  Saved
# Finished
# Get Data for :  APPN
# C:/Users/hansf/git/python/aktie/Python4Finance/APPN.csv  Saved
# Finished
# Get Data for :  APPS
# C:/Users/hansf/git/python/aktie/Python4Finance/APPS.csv  Saved
# Finished
# Get Data for :  APRN
# C:/Users/hansf/git/python/aktie/Python4Finance/APRN.csv  Saved
# Finished
# Get Data for :  APT
# C:/Users/hansf/git/python/aktie/Python4Finance/APT.csv  Saved
# Finished
# Get Data for :  APTS
# C:/Users/hansf/git/python/aktie/Python4Finance/APTS.csv  Saved
# Finished
# Get Data for :  APTV
# C:/Users/hansf/git/python/aktie/Python4Finance/APTV.csv  Saved
# Finished
# Get Data for :  APVO
# C:/Users/hansf/git/python/aktie/Python4Finance/APVO.csv  Saved
# Finished
# Get Data for :  APYX
# C:/Users/hansf/git/python/aktie/Python4Finance/APYX.csv  Saved
# Finished
# Get Data for :  AQB
# C:/Users/hansf/git/python/aktie/Python4Finance/AQB.csv  Saved
# Finished
# Get Data for :  AQMS
# C:/Users/hansf/git/python/aktie/Python4Finance/AQMS.csv  Saved
# Finished
# Get Data for :  AQUA
# C:/Users/hansf/git/python/aktie/Python4Finance/AQUA.csv  Saved
# Finished
# Get Data for :  AR
# C:/Users/hansf/git/python/aktie/Python4Finance/AR.csv  Saved
# Finished
# Get Data for :  ARA
# - ARA: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/ARA.csv  Saved
# Finished
# Get Data for :  ARAV
# C:/Users/hansf/git/python/aktie/Python4Finance/ARAV.csv  Saved
# Finished
# Get Data for :  ARAY
# C:/Users/hansf/git/python/aktie/Python4Finance/ARAY.csv  Saved
# Finished
# Get Data for :  ARC
# C:/Users/hansf/git/python/aktie/Python4Finance/ARC.csv  Saved
# Finished
# Get Data for :  ARCB
# C:/Users/hansf/git/python/aktie/Python4Finance/ARCB.csv  Saved
# Finished
# Get Data for :  ARCH
# C:/Users/hansf/git/python/aktie/Python4Finance/ARCH.csv  Saved
# Finished
# Get Data for :  ARDX
# C:/Users/hansf/git/python/aktie/Python4Finance/ARDX.csv  Saved
# Finished
# Get Data for :  ARE
# C:/Users/hansf/git/python/aktie/Python4Finance/ARE.csv  Saved
# Finished
# Get Data for :  ARES
# C:/Users/hansf/git/python/aktie/Python4Finance/ARES.csv  Saved
# Finished
# Get Data for :  ARGO
# C:/Users/hansf/git/python/aktie/Python4Finance/ARGO.csv  Saved
# Finished
# Get Data for :  ARI
# C:/Users/hansf/git/python/aktie/Python4Finance/ARI.csv  Saved
# Finished
# Get Data for :  ARKR
# C:/Users/hansf/git/python/aktie/Python4Finance/ARKR.csv  Saved
# Finished
# Get Data for :  ARL
# C:/Users/hansf/git/python/aktie/Python4Finance/ARL.csv  Saved
# Finished
# Get Data for :  ARLO
# C:/Users/hansf/git/python/aktie/Python4Finance/ARLO.csv  Saved
# Finished
# Get Data for :  ARMK
# C:/Users/hansf/git/python/aktie/Python4Finance/ARMK.csv  Saved
# Finished
# Get Data for :  ARNA
# C:/Users/hansf/git/python/aktie/Python4Finance/ARNA.csv  Saved
# Finished
# Get Data for :  ARNC
# C:/Users/hansf/git/python/aktie/Python4Finance/ARNC.csv  Saved
# Finished
# Get Data for :  AROC
# C:/Users/hansf/git/python/aktie/Python4Finance/AROC.csv  Saved
# Finished
# Get Data for :  AROW
# C:/Users/hansf/git/python/aktie/Python4Finance/AROW.csv  Saved
# Finished
# Get Data for :  ARPO
# - ARPO: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/ARPO.csv  Saved
# Finished
# Get Data for :  ARR
# C:/Users/hansf/git/python/aktie/Python4Finance/ARR.csv  Saved
# Finished
# Get Data for :  ARTNA
# C:/Users/hansf/git/python/aktie/Python4Finance/ARTNA.csv  Saved
# Finished
# Get Data for :  ARTW
# C:/Users/hansf/git/python/aktie/Python4Finance/ARTW.csv  Saved
# Finished
# Get Data for :  ARVN
# C:/Users/hansf/git/python/aktie/Python4Finance/ARVN.csv  Saved
# Finished
# Get Data for :  ARW
# C:/Users/hansf/git/python/aktie/Python4Finance/ARW.csv  Saved
# Finished
# Get Data for :  ARWR
# C:/Users/hansf/git/python/aktie/Python4Finance/ARWR.csv  Saved
# Finished
# Get Data for :  ASB
# C:/Users/hansf/git/python/aktie/Python4Finance/ASB.csv  Saved
# Finished
# Get Data for :  ASFI
# - ASFI: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/ASFI.csv  Saved
# Finished
# Get Data for :  ASGN
# C:/Users/hansf/git/python/aktie/Python4Finance/ASGN.csv  Saved
# Finished
# Get Data for :  ASH
# C:/Users/hansf/git/python/aktie/Python4Finance/ASH.csv  Saved
# Finished
# Get Data for :  ASIX
# C:/Users/hansf/git/python/aktie/Python4Finance/ASIX.csv  Saved
# Finished
# Get Data for :  ASMB
# C:/Users/hansf/git/python/aktie/Python4Finance/ASMB.csv  Saved
# Finished
# Get Data for :  ASNA
# - ASNA: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/ASNA.csv  Saved
# Finished
# Get Data for :  ASPN
# C:/Users/hansf/git/python/aktie/Python4Finance/ASPN.csv  Saved
# Finished
# Get Data for :  ASPS
# C:/Users/hansf/git/python/aktie/Python4Finance/ASPS.csv  Saved
# Finished
# Get Data for :  ASRT
# C:/Users/hansf/git/python/aktie/Python4Finance/ASRT.csv  Saved
# Finished
# Get Data for :  ASRV
# C:/Users/hansf/git/python/aktie/Python4Finance/ASRV.csv  Saved
# Finished
# Get Data for :  ASTC
# C:/Users/hansf/git/python/aktie/Python4Finance/ASTC.csv  Saved
# Finished
# Get Data for :  ASTE
# C:/Users/hansf/git/python/aktie/Python4Finance/ASTE.csv  Saved
# Finished
# Get Data for :  ASUR
# C:/Users/hansf/git/python/aktie/Python4Finance/ASUR.csv  Saved
# Finished
# Get Data for :  ASYS
# C:/Users/hansf/git/python/aktie/Python4Finance/ASYS.csv  Saved
# Finished
# Get Data for :  ATEC
# C:/Users/hansf/git/python/aktie/Python4Finance/ATEC.csv  Saved
# Finished
# Get Data for :  ATEN
# C:/Users/hansf/git/python/aktie/Python4Finance/ATEN.csv  Saved
# Finished
# Get Data for :  ATGE
# C:/Users/hansf/git/python/aktie/Python4Finance/ATGE.csv  Saved
# Finished
# Get Data for :  ATH
# C:/Users/hansf/git/python/aktie/Python4Finance/ATH.csv  Saved
# Finished
# Get Data for :  ATHX
# C:/Users/hansf/git/python/aktie/Python4Finance/ATHX.csv  Saved
# Finished
# Get Data for :  ATI
# C:/Users/hansf/git/python/aktie/Python4Finance/ATI.csv  Saved
# Finished
# Get Data for :  ATKR
# C:/Users/hansf/git/python/aktie/Python4Finance/ATKR.csv  Saved
# Finished
# Get Data for :  ATLC
# C:/Users/hansf/git/python/aktie/Python4Finance/ATLC.csv  Saved
# Finished
# Get Data for :  ATLO
# C:/Users/hansf/git/python/aktie/Python4Finance/ATLO.csv  Saved
# Finished
# Get Data for :  ATNI
# C:/Users/hansf/git/python/aktie/Python4Finance/ATNI.csv  Saved
# Finished
# Get Data for :  ATNM
# C:/Users/hansf/git/python/aktie/Python4Finance/ATNM.csv  Saved
# Finished
# Get Data for :  ATNX
# C:/Users/hansf/git/python/aktie/Python4Finance/ATNX.csv  Saved
# Finished
# Get Data for :  ATO
# C:/Users/hansf/git/python/aktie/Python4Finance/ATO.csv  Saved
# Finished
# Get Data for :  ATOS
# C:/Users/hansf/git/python/aktie/Python4Finance/ATOS.csv  Saved
# Finished
# Get Data for :  ATR
# C:/Users/hansf/git/python/aktie/Python4Finance/ATR.csv  Saved
# Finished
# Get Data for :  ATRA
# C:/Users/hansf/git/python/aktie/Python4Finance/ATRA.csv  Saved
# Finished
# Get Data for :  ATRC
# C:/Users/hansf/git/python/aktie/Python4Finance/ATRC.csv  Saved
# Finished
# Get Data for :  ATRI
# C:/Users/hansf/git/python/aktie/Python4Finance/ATRI.csv  Saved
# Finished
# Get Data for :  ATRO
# C:/Users/hansf/git/python/aktie/Python4Finance/ATRO.csv  Saved
# Finished
# Get Data for :  ATRS
# C:/Users/hansf/git/python/aktie/Python4Finance/ATRS.csv  Saved
# Finished
# Get Data for :  ATSG
# C:/Users/hansf/git/python/aktie/Python4Finance/ATSG.csv  Saved
# Finished
# Get Data for :  ATUS
# C:/Users/hansf/git/python/aktie/Python4Finance/ATUS.csv  Saved
# Finished
# Get Data for :  ATVI
# C:/Users/hansf/git/python/aktie/Python4Finance/ATVI.csv  Saved
# Finished
# Get Data for :  AUBN
# C:/Users/hansf/git/python/aktie/Python4Finance/AUBN.csv  Saved
# Finished
# Get Data for :  AUMN
# C:/Users/hansf/git/python/aktie/Python4Finance/AUMN.csv  Saved
# Finished
# Get Data for :  AUTO
# C:/Users/hansf/git/python/aktie/Python4Finance/AUTO.csv  Saved
# Finished
# Get Data for :  AVA
# C:/Users/hansf/git/python/aktie/Python4Finance/AVA.csv  Saved
# Finished
# Get Data for :  AVAV
# C:/Users/hansf/git/python/aktie/Python4Finance/AVAV.csv  Saved
# Finished
# Get Data for :  AVB
# C:/Users/hansf/git/python/aktie/Python4Finance/AVB.csv  Saved
# Finished
# Get Data for :  AVD
# C:/Users/hansf/git/python/aktie/Python4Finance/AVD.csv  Saved
# Finished
# Get Data for :  AVEO
# C:/Users/hansf/git/python/aktie/Python4Finance/AVEO.csv  Saved
# Finished
# Get Data for :  AVGO
# C:/Users/hansf/git/python/aktie/Python4Finance/AVGO.csv  Saved
# Finished
# Get Data for :  AVGR
# C:/Users/hansf/git/python/aktie/Python4Finance/AVGR.csv  Saved
# Finished
# Get Data for :  AVID
# C:/Users/hansf/git/python/aktie/Python4Finance/AVID.csv  Saved
# Finished
# Get Data for :  AVLR
# C:/Users/hansf/git/python/aktie/Python4Finance/AVLR.csv  Saved
# Finished
# Get Data for :  AVNS
# C:/Users/hansf/git/python/aktie/Python4Finance/AVNS.csv  Saved
# Finished
# Get Data for :  AVNW
# C:/Users/hansf/git/python/aktie/Python4Finance/AVNW.csv  Saved
# Finished
# Get Data for :  AVRO
# C:/Users/hansf/git/python/aktie/Python4Finance/AVRO.csv  Saved
# Finished
# Get Data for :  AVT
# C:/Users/hansf/git/python/aktie/Python4Finance/AVT.csv  Saved
# Finished
# Get Data for :  AVTR
# C:/Users/hansf/git/python/aktie/Python4Finance/AVTR.csv  Saved
# Finished
# Get Data for :  AVXL
# C:/Users/hansf/git/python/aktie/Python4Finance/AVXL.csv  Saved
# Finished
# Get Data for :  AVY
# C:/Users/hansf/git/python/aktie/Python4Finance/AVY.csv  Saved
# Finished
# Get Data for :  AVYA
# C:/Users/hansf/git/python/aktie/Python4Finance/AVYA.csv  Saved
# Finished
# Get Data for :  AWI
# C:/Users/hansf/git/python/aktie/Python4Finance/AWI.csv  Saved
# Finished
# Get Data for :  AWK
# C:/Users/hansf/git/python/aktie/Python4Finance/AWK.csv  Saved
# Finished
# Get Data for :  AWR
# C:/Users/hansf/git/python/aktie/Python4Finance/AWR.csv  Saved
# Finished
# Get Data for :  AWRE
# C:/Users/hansf/git/python/aktie/Python4Finance/AWRE.csv  Saved
# Finished
# Get Data for :  AWSM
# - AWSM: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/AWSM.csv  Saved
# Finished
# Get Data for :  AX
# C:/Users/hansf/git/python/aktie/Python4Finance/AX.csv  Saved
# Finished
# Get Data for :  AXAS
# C:/Users/hansf/git/python/aktie/Python4Finance/AXAS.csv  Saved
# Finished
# Get Data for :  AXDX
# C:/Users/hansf/git/python/aktie/Python4Finance/AXDX.csv  Saved
# Finished
# Get Data for :  AXE
# - AXE: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/AXE.csv  Saved
# Finished
# Get Data for :  AXGN
# C:/Users/hansf/git/python/aktie/Python4Finance/AXGN.csv  Saved
# Finished
# Get Data for :  AXL
# C:/Users/hansf/git/python/aktie/Python4Finance/AXL.csv  Saved
# Finished
# Get Data for :  AXNX
# C:/Users/hansf/git/python/aktie/Python4Finance/AXNX.csv  Saved
# Finished
# Get Data for :  AXP
# C:/Users/hansf/git/python/aktie/Python4Finance/AXP.csv  Saved
# Finished
# Get Data for :  AXR
# C:/Users/hansf/git/python/aktie/Python4Finance/AXR.csv  Saved
# Finished
# Get Data for :  AXS
# C:/Users/hansf/git/python/aktie/Python4Finance/AXS.csv  Saved
# Finished
# Get Data for :  AXSM
# C:/Users/hansf/git/python/aktie/Python4Finance/AXSM.csv  Saved
# Finished
# Get Data for :  AXTA
# C:/Users/hansf/git/python/aktie/Python4Finance/AXTA.csv  Saved
# Finished
# Get Data for :  AXTI
# C:/Users/hansf/git/python/aktie/Python4Finance/AXTI.csv  Saved
# Finished
# Get Data for :  AYI
# C:/Users/hansf/git/python/aktie/Python4Finance/AYI.csv  Saved
# Finished
# Get Data for :  AYX
# C:/Users/hansf/git/python/aktie/Python4Finance/AYX.csv  Saved
# Finished
# Get Data for :  AZO
# C:/Users/hansf/git/python/aktie/Python4Finance/AZO.csv  Saved
# Finished
# Get Data for :  AZPN
# C:/Users/hansf/git/python/aktie/Python4Finance/AZPN.csv  Saved
# Finished
# Get Data for :  AZZ
# C:/Users/hansf/git/python/aktie/Python4Finance/AZZ.csv  Saved
# Finished
# Get Data for :  B
# C:/Users/hansf/git/python/aktie/Python4Finance/B.csv  Saved
# Finished
# Get Data for :  BA
# C:/Users/hansf/git/python/aktie/Python4Finance/BA.csv  Saved
# Finished
# Get Data for :  BAC
# C:/Users/hansf/git/python/aktie/Python4Finance/BAC.csv  Saved
# Finished
# Get Data for :  BAH
# C:/Users/hansf/git/python/aktie/Python4Finance/BAH.csv  Saved
# Finished
# Get Data for :  BANC
# C:/Users/hansf/git/python/aktie/Python4Finance/BANC.csv  Saved
# Finished
# Get Data for :  BAND
# C:/Users/hansf/git/python/aktie/Python4Finance/BAND.csv  Saved
# Finished
# Get Data for :  BANF
# C:/Users/hansf/git/python/aktie/Python4Finance/BANF.csv  Saved
# Finished
# Get Data for :  BANR
# C:/Users/hansf/git/python/aktie/Python4Finance/BANR.csv  Saved
# Finished
# Get Data for :  BASI
# - BASI: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/BASI.csv  Saved
# Finished
# Get Data for :  BATRA
# C:/Users/hansf/git/python/aktie/Python4Finance/BATRA.csv  Saved
# Finished
# Get Data for :  BATRK
# C:/Users/hansf/git/python/aktie/Python4Finance/BATRK.csv  Saved
# Finished
# Get Data for :  BAX
# C:/Users/hansf/git/python/aktie/Python4Finance/BAX.csv  Saved
# Finished
# Get Data for :  BBBY
# C:/Users/hansf/git/python/aktie/Python4Finance/BBBY.csv  Saved
# Finished
# Get Data for :  BBCP
# C:/Users/hansf/git/python/aktie/Python4Finance/BBCP.csv  Saved
# Finished
# Get Data for :  BBGI
# C:/Users/hansf/git/python/aktie/Python4Finance/BBGI.csv  Saved
# Finished
# Get Data for :  BBSI
# C:/Users/hansf/git/python/aktie/Python4Finance/BBSI.csv  Saved
# Finished
# Get Data for :  BBW
# C:/Users/hansf/git/python/aktie/Python4Finance/BBW.csv  Saved
# Finished
# Get Data for :  BBY
# C:/Users/hansf/git/python/aktie/Python4Finance/BBY.csv  Saved
# Finished
# Get Data for :  BC
# C:/Users/hansf/git/python/aktie/Python4Finance/BC.csv  Saved
# Finished
# Get Data for :  BCBP
# C:/Users/hansf/git/python/aktie/Python4Finance/BCBP.csv  Saved
# Finished
# Get Data for :  BCC
# C:/Users/hansf/git/python/aktie/Python4Finance/BCC.csv  Saved
# Finished
# Get Data for :  BCEI
# - BCEI: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/BCEI.csv  Saved
# Finished
# Get Data for :  BCLI
# C:/Users/hansf/git/python/aktie/Python4Finance/BCLI.csv  Saved
# Finished
# Get Data for :  BCO
# C:/Users/hansf/git/python/aktie/Python4Finance/BCO.csv  Saved
# Finished
# Get Data for :  BCOR
# C:/Users/hansf/git/python/aktie/Python4Finance/BCOR.csv  Saved
# Finished
# Get Data for :  BCOV
# C:/Users/hansf/git/python/aktie/Python4Finance/BCOV.csv  Saved
# Finished
# Get Data for :  BCPC
# C:/Users/hansf/git/python/aktie/Python4Finance/BCPC.csv  Saved
# Finished
# Get Data for :  BCRX
# C:/Users/hansf/git/python/aktie/Python4Finance/BCRX.csv  Saved
# Finished
# Get Data for :  BDC
# C:/Users/hansf/git/python/aktie/Python4Finance/BDC.csv  Saved
# Finished
# Get Data for :  BDGE
# - BDGE: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/BDGE.csv  Saved
# Finished
# Get Data for :  BDL
# C:/Users/hansf/git/python/aktie/Python4Finance/BDL.csv  Saved
# Finished
# Get Data for :  BDN
# C:/Users/hansf/git/python/aktie/Python4Finance/BDN.csv  Saved
# Finished
# Get Data for :  BDSI
# C:/Users/hansf/git/python/aktie/Python4Finance/BDSI.csv  Saved
# Finished
# Get Data for :  BDX
# C:/Users/hansf/git/python/aktie/Python4Finance/BDX.csv  Saved
# Finished
# Get Data for :  BE
# C:/Users/hansf/git/python/aktie/Python4Finance/BE.csv  Saved
# Finished
# Get Data for :  BEAT
# C:/Users/hansf/git/python/aktie/Python4Finance/BEAT.csv  Saved
# Finished
# Get Data for :  BECN
# C:/Users/hansf/git/python/aktie/Python4Finance/BECN.csv  Saved
# Finished
# Get Data for :  BELFA
# C:/Users/hansf/git/python/aktie/Python4Finance/BELFA.csv  Saved
# Finished
# Get Data for :  BELFB
# C:/Users/hansf/git/python/aktie/Python4Finance/BELFB.csv  Saved
# Finished
# Get Data for :  BEN
# C:/Users/hansf/git/python/aktie/Python4Finance/BEN.csv  Saved
# Finished
# Get Data for :  BERY
# C:/Users/hansf/git/python/aktie/Python4Finance/BERY.csv  Saved
# Finished
# Get Data for :  BFAM
# C:/Users/hansf/git/python/aktie/Python4Finance/BFAM.csv  Saved
# Finished
# Get Data for :  BFIN
# C:/Users/hansf/git/python/aktie/Python4Finance/BFIN.csv  Saved
# Finished
# Get Data for :  BFS
# C:/Users/hansf/git/python/aktie/Python4Finance/BFS.csv  Saved
# Finished
# Get Data for :  BFST
# C:/Users/hansf/git/python/aktie/Python4Finance/BFST.csv  Saved
# Finished
# Get Data for :  BG
# C:/Users/hansf/git/python/aktie/Python4Finance/BG.csv  Saved
# Finished
# Get Data for :  BGCP
# C:/Users/hansf/git/python/aktie/Python4Finance/BGCP.csv  Saved
# Finished
# Get Data for :  BGFV
# C:/Users/hansf/git/python/aktie/Python4Finance/BGFV.csv  Saved
# Finished
# Get Data for :  BGS
# C:/Users/hansf/git/python/aktie/Python4Finance/BGS.csv  Saved
# Finished
# Get Data for :  BGSF
# C:/Users/hansf/git/python/aktie/Python4Finance/BGSF.csv  Saved
# Finished
# Get Data for :  BH
# C:/Users/hansf/git/python/aktie/Python4Finance/BH.csv  Saved
# Finished
# Get Data for :  BHB
# C:/Users/hansf/git/python/aktie/Python4Finance/BHB.csv  Saved
# Finished
# Get Data for :  BHE
# C:/Users/hansf/git/python/aktie/Python4Finance/BHE.csv  Saved
# Finished
# Get Data for :  BHF
# C:/Users/hansf/git/python/aktie/Python4Finance/BHF.csv  Saved
# Finished
# Get Data for :  BHLB
# C:/Users/hansf/git/python/aktie/Python4Finance/BHLB.csv  Saved
# Finished
# Get Data for :  BHR
# C:/Users/hansf/git/python/aktie/Python4Finance/BHR.csv  Saved
# Finished
# Get Data for :  BHVN
# C:/Users/hansf/git/python/aktie/Python4Finance/BHVN.csv  Saved
# Finished
# Get Data for :  BIG
# C:/Users/hansf/git/python/aktie/Python4Finance/BIG.csv  Saved
# Finished
# Get Data for :  BIIB
# C:/Users/hansf/git/python/aktie/Python4Finance/BIIB.csv  Saved
# Finished
# Get Data for :  BIO
# C:/Users/hansf/git/python/aktie/Python4Finance/BIO.csv  Saved
# Finished
# Get Data for :  BIOC
# C:/Users/hansf/git/python/aktie/Python4Finance/BIOC.csv  Saved
# Finished
# Get Data for :  BIOL
# C:/Users/hansf/git/python/aktie/Python4Finance/BIOL.csv  Saved
# Finished
# Get Data for :  BJ
# C:/Users/hansf/git/python/aktie/Python4Finance/BJ.csv  Saved
# Finished
# Get Data for :  BJRI
# C:/Users/hansf/git/python/aktie/Python4Finance/BJRI.csv  Saved
# Finished
# Get Data for :  BK
# C:/Users/hansf/git/python/aktie/Python4Finance/BK.csv  Saved
# Finished
# Get Data for :  BKD
# C:/Users/hansf/git/python/aktie/Python4Finance/BKD.csv  Saved
# Finished
# Get Data for :  BKE
# C:/Users/hansf/git/python/aktie/Python4Finance/BKE.csv  Saved
# Finished
# Get Data for :  BKH
# C:/Users/hansf/git/python/aktie/Python4Finance/BKH.csv  Saved
# Finished
# Get Data for :  BKI
# C:/Users/hansf/git/python/aktie/Python4Finance/BKI.csv  Saved
# Finished
# Get Data for :  BKNG
# C:/Users/hansf/git/python/aktie/Python4Finance/BKNG.csv  Saved
# Finished
# Get Data for :  BKSC
# C:/Users/hansf/git/python/aktie/Python4Finance/BKSC.csv  Saved
# Finished
# Get Data for :  BKTI
# C:/Users/hansf/git/python/aktie/Python4Finance/BKTI.csv  Saved
# Finished
# Get Data for :  BKU
# C:/Users/hansf/git/python/aktie/Python4Finance/BKU.csv  Saved
# Finished
# Get Data for :  BL
# C:/Users/hansf/git/python/aktie/Python4Finance/BL.csv  Saved
# Finished
# Get Data for :  BLBD
# C:/Users/hansf/git/python/aktie/Python4Finance/BLBD.csv  Saved
# Finished
# Get Data for :  BLCM
# C:/Users/hansf/git/python/aktie/Python4Finance/BLCM.csv  Saved
# Finished
# Get Data for :  BLD
# C:/Users/hansf/git/python/aktie/Python4Finance/BLD.csv  Saved
# Finished
# Get Data for :  BLDR
# C:/Users/hansf/git/python/aktie/Python4Finance/BLDR.csv  Saved
# Finished
# Get Data for :  BLFS
# C:/Users/hansf/git/python/aktie/Python4Finance/BLFS.csv  Saved
# Finished
# Get Data for :  BLK
# C:/Users/hansf/git/python/aktie/Python4Finance/BLK.csv  Saved
# Finished
# Get Data for :  BLKB
# C:/Users/hansf/git/python/aktie/Python4Finance/BLKB.csv  Saved
# Finished
# Get Data for :  BLL
# C:/Users/hansf/git/python/aktie/Python4Finance/BLL.csv  Saved
# Finished
# Get Data for :  BLMN
# C:/Users/hansf/git/python/aktie/Python4Finance/BLMN.csv  Saved
# Finished
# Get Data for :  BLUE
# C:/Users/hansf/git/python/aktie/Python4Finance/BLUE.csv  Saved
# Finished
# Get Data for :  BMCH
# - BMCH: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/BMCH.csv  Saved
# Finished
# Get Data for :  BMI
# C:/Users/hansf/git/python/aktie/Python4Finance/BMI.csv  Saved
# Finished
# Get Data for :  BMRC
# C:/Users/hansf/git/python/aktie/Python4Finance/BMRC.csv  Saved
# Finished
# Get Data for :  BMRN
# C:/Users/hansf/git/python/aktie/Python4Finance/BMRN.csv  Saved
# Finished
# Get Data for :  BMTC
# C:/Users/hansf/git/python/aktie/Python4Finance/BMTC.csv  Saved
# Finished
# Get Data for :  BMY
# C:/Users/hansf/git/python/aktie/Python4Finance/BMY.csv  Saved
# Finished
# Get Data for :  BNED
# C:/Users/hansf/git/python/aktie/Python4Finance/BNED.csv  Saved
# Finished
# Get Data for :  BNFT
# C:/Users/hansf/git/python/aktie/Python4Finance/BNFT.csv  Saved
# Finished
# Get Data for :  BOCH
# - BOCH: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/BOCH.csv  Saved
# Finished
# Get Data for :  BOH
# C:/Users/hansf/git/python/aktie/Python4Finance/BOH.csv  Saved
# Finished
# Get Data for :  BOKF
# C:/Users/hansf/git/python/aktie/Python4Finance/BOKF.csv  Saved
# Finished
# Get Data for :  BOMN
# C:/Users/hansf/git/python/aktie/Python4Finance/BOMN.csv  Saved
# Finished
# Get Data for :  BOOM
# C:/Users/hansf/git/python/aktie/Python4Finance/BOOM.csv  Saved
# Finished
# Get Data for :  BOOT
# C:/Users/hansf/git/python/aktie/Python4Finance/BOOT.csv  Saved
# Finished
# Get Data for :  BOTJ
# C:/Users/hansf/git/python/aktie/Python4Finance/BOTJ.csv  Saved
# Finished
# Get Data for :  BOX
# C:/Users/hansf/git/python/aktie/Python4Finance/BOX.csv  Saved
# Finished
# Get Data for :  BPFH
# - BPFH: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/BPFH.csv  Saved
# Finished
# Get Data for :  BPMC
# C:/Users/hansf/git/python/aktie/Python4Finance/BPMC.csv  Saved
# Finished
# Get Data for :  BPOP
# C:/Users/hansf/git/python/aktie/Python4Finance/BPOP.csv  Saved
# Finished
# Get Data for :  BPRN
# C:/Users/hansf/git/python/aktie/Python4Finance/BPRN.csv  Saved
# Finished
# Get Data for :  BPTH
# C:/Users/hansf/git/python/aktie/Python4Finance/BPTH.csv  Saved
# Finished
# Get Data for :  BR
# C:/Users/hansf/git/python/aktie/Python4Finance/BR.csv  Saved
# Finished
# Get Data for :  BRC
# C:/Users/hansf/git/python/aktie/Python4Finance/BRC.csv  Saved
# Finished
# Get Data for :  BREW
# - BREW: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/BREW.csv  Saved
# Finished
# Get Data for :  BRG
# C:/Users/hansf/git/python/aktie/Python4Finance/BRG.csv  Saved
# Finished
# Get Data for :  BRID
# C:/Users/hansf/git/python/aktie/Python4Finance/BRID.csv  Saved
# Finished
# Get Data for :  BRKL
# C:/Users/hansf/git/python/aktie/Python4Finance/BRKL.csv  Saved
# Finished
# Get Data for :  BRKR
# C:/Users/hansf/git/python/aktie/Python4Finance/BRKR.csv  Saved
# Finished
# Get Data for :  BRKS
# - BRKS: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/BRKS.csv  Saved
# Finished
# Get Data for :  BRN
# C:/Users/hansf/git/python/aktie/Python4Finance/BRN.csv  Saved
# Finished
# Get Data for :  BRO
# C:/Users/hansf/git/python/aktie/Python4Finance/BRO.csv  Saved
# Finished
# Get Data for :  BRT
# C:/Users/hansf/git/python/aktie/Python4Finance/BRT.csv  Saved
# Finished
# Get Data for :  BRX
# C:/Users/hansf/git/python/aktie/Python4Finance/BRX.csv  Saved
# Finished
# Get Data for :  BRY
# C:/Users/hansf/git/python/aktie/Python4Finance/BRY.csv  Saved
# Finished
# Get Data for :  BSET
# C:/Users/hansf/git/python/aktie/Python4Finance/BSET.csv  Saved
# Finished
# Get Data for :  BSGM
# C:/Users/hansf/git/python/aktie/Python4Finance/BSGM.csv  Saved
# Finished
# Get Data for :  BSQR
# C:/Users/hansf/git/python/aktie/Python4Finance/BSQR.csv  Saved
# Finished
# Get Data for :  BSRR
# C:/Users/hansf/git/python/aktie/Python4Finance/BSRR.csv  Saved
# Finished
# Get Data for :  BSTC
# - BSTC: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/BSTC.csv  Saved
# Finished
# Get Data for :  BSX
# C:/Users/hansf/git/python/aktie/Python4Finance/BSX.csv  Saved
# Finished
# Get Data for :  BTN
# C:/Users/hansf/git/python/aktie/Python4Finance/BTN.csv  Saved
# Finished
# Get Data for :  BTU
# C:/Users/hansf/git/python/aktie/Python4Finance/BTU.csv  Saved
# Finished
# Get Data for :  BURL
# C:/Users/hansf/git/python/aktie/Python4Finance/BURL.csv  Saved
# Finished
# Get Data for :  BUSE
# C:/Users/hansf/git/python/aktie/Python4Finance/BUSE.csv  Saved
# Finished
# Get Data for :  BV
# C:/Users/hansf/git/python/aktie/Python4Finance/BV.csv  Saved
# Finished
# Get Data for :  BW
# C:/Users/hansf/git/python/aktie/Python4Finance/BW.csv  Saved
# Finished
# Get Data for :  BWA
# C:/Users/hansf/git/python/aktie/Python4Finance/BWA.csv  Saved
# Finished
# Get Data for :  BWEN
# C:/Users/hansf/git/python/aktie/Python4Finance/BWEN.csv  Saved
# Finished
# Get Data for :  BWFG
# C:/Users/hansf/git/python/aktie/Python4Finance/BWFG.csv  Saved
# Finished
# Get Data for :  BWXT
# C:/Users/hansf/git/python/aktie/Python4Finance/BWXT.csv  Saved
# Finished
# Get Data for :  BXC
# C:/Users/hansf/git/python/aktie/Python4Finance/BXC.csv  Saved
# Finished
# Get Data for :  BXMT
# C:/Users/hansf/git/python/aktie/Python4Finance/BXMT.csv  Saved
# Finished
# Get Data for :  BXP
# C:/Users/hansf/git/python/aktie/Python4Finance/BXP.csv  Saved
# Finished
# Get Data for :  BXS
# - BXS: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/BXS.csv  Saved
# Finished
# Get Data for :  BY
# C:/Users/hansf/git/python/aktie/Python4Finance/BY.csv  Saved
# Finished
# Get Data for :  BYD
# C:/Users/hansf/git/python/aktie/Python4Finance/BYD.csv  Saved
# Finished
# Get Data for :  BYFC
# C:/Users/hansf/git/python/aktie/Python4Finance/BYFC.csv  Saved
# Finished
# Get Data for :  BYND
# C:/Users/hansf/git/python/aktie/Python4Finance/BYND.csv  Saved
# Finished
# Get Data for :  BZH
# C:/Users/hansf/git/python/aktie/Python4Finance/BZH.csv  Saved
# Finished
# Get Data for :  C
# C:/Users/hansf/git/python/aktie/Python4Finance/C.csv  Saved
# Finished
# Get Data for :  CABO
# C:/Users/hansf/git/python/aktie/Python4Finance/CABO.csv  Saved
# Finished
# Get Data for :  CAC
# C:/Users/hansf/git/python/aktie/Python4Finance/CAC.csv  Saved
# Finished
# Get Data for :  CACC
# C:/Users/hansf/git/python/aktie/Python4Finance/CACC.csv  Saved
# Finished
# Get Data for :  CACI
# C:/Users/hansf/git/python/aktie/Python4Finance/CACI.csv  Saved
# Finished
# Get Data for :  CADE
# C:/Users/hansf/git/python/aktie/Python4Finance/CADE.csv  Saved
# Finished
# Get Data for :  CAG
# C:/Users/hansf/git/python/aktie/Python4Finance/CAG.csv  Saved
# Finished
# Get Data for :  CAH
# C:/Users/hansf/git/python/aktie/Python4Finance/CAH.csv  Saved
# Finished
# Get Data for :  CAI
# - CAI: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/CAI.csv  Saved
# Finished
# Get Data for :  CAKE
# C:/Users/hansf/git/python/aktie/Python4Finance/CAKE.csv  Saved
# Finished
# Get Data for :  CAL
# C:/Users/hansf/git/python/aktie/Python4Finance/CAL.csv  Saved
# Finished
# Get Data for :  CALA
# C:/Users/hansf/git/python/aktie/Python4Finance/CALA.csv  Saved
# Finished
# Get Data for :  CALM
# C:/Users/hansf/git/python/aktie/Python4Finance/CALM.csv  Saved
# Finished
# Get Data for :  CALX
# C:/Users/hansf/git/python/aktie/Python4Finance/CALX.csv  Saved
# Finished
# Get Data for :  CAMP
# C:/Users/hansf/git/python/aktie/Python4Finance/CAMP.csv  Saved
# Finished
# Get Data for :  CAPR
# C:/Users/hansf/git/python/aktie/Python4Finance/CAPR.csv  Saved
# Finished
# Get Data for :  CAR
# C:/Users/hansf/git/python/aktie/Python4Finance/CAR.csv  Saved
# Finished
# Get Data for :  CARA
# C:/Users/hansf/git/python/aktie/Python4Finance/CARA.csv  Saved
# Finished
# Get Data for :  CARG
# C:/Users/hansf/git/python/aktie/Python4Finance/CARG.csv  Saved
# Finished
# Get Data for :  CARS
# C:/Users/hansf/git/python/aktie/Python4Finance/CARS.csv  Saved
# Finished
# Get Data for :  CASA
# C:/Users/hansf/git/python/aktie/Python4Finance/CASA.csv  Saved
# Finished
# Get Data for :  CASH
# C:/Users/hansf/git/python/aktie/Python4Finance/CASH.csv  Saved
# Finished
# Get Data for :  CASI
# C:/Users/hansf/git/python/aktie/Python4Finance/CASI.csv  Saved
# Finished
# Get Data for :  CASS
# C:/Users/hansf/git/python/aktie/Python4Finance/CASS.csv  Saved
# Finished
# Get Data for :  CASY
# ...
# C:/Users/hansf/git/python/aktie/Python4Finance/VISL.csv  Saved
# Finished
# Get Data for :  VSTO
# C:/Users/hansf/git/python/aktie/Python4Finance/VSTO.csv  Saved
# Finished
# Get Data for :  VC
# C:/Users/hansf/git/python/aktie/Python4Finance/VC.csv  Saved
# Finished
# Get Data for :  VST
# C:/Users/hansf/git/python/aktie/Python4Finance/VST.csv  Saved
# Finished
# Get Data for :  VSI
# - VSI: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/VSI.csv  Saved
# Finished
# Get Data for :  VSLR
# - VSLR: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/VSLR.csv  Saved
# Finished
# Get Data for :  VVUS
# - VVUS: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/VVUS.csv  Saved
# Finished
# Get Data for :  VMW
# C:/Users/hansf/git/python/aktie/Python4Finance/VMW.csv  Saved
# Finished
# Get Data for :  VCRA
# C:/Users/hansf/git/python/aktie/Python4Finance/VCRA.csv  Saved
# Finished
# Get Data for :  VNRX
# C:/Users/hansf/git/python/aktie/Python4Finance/VNRX.csv  Saved
# Finished
# Get Data for :  VISI
# - VISI: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/VISI.csv  Saved
# Finished
# Get Data for :  VG
# C:/Users/hansf/git/python/aktie/Python4Finance/VG.csv  Saved
# Finished
# Get Data for :  VNO
# C:/Users/hansf/git/python/aktie/Python4Finance/VNO.csv  Saved
# Finished
# Get Data for :  VOXX
# C:/Users/hansf/git/python/aktie/Python4Finance/VOXX.csv  Saved
# Finished
# Get Data for :  VOYA
# C:/Users/hansf/git/python/aktie/Python4Finance/VOYA.csv  Saved
# Finished
# Get Data for :  VYGR
# C:/Users/hansf/git/python/aktie/Python4Finance/VYGR.csv  Saved
# Finished
# Get Data for :  VSEC
# C:/Users/hansf/git/python/aktie/Python4Finance/VSEC.csv  Saved
# Finished
# Get Data for :  VTVT
# C:/Users/hansf/git/python/aktie/Python4Finance/VTVT.csv  Saved
# Finished
# Get Data for :  VMC
# C:/Users/hansf/git/python/aktie/Python4Finance/VMC.csv  Saved
# Finished
# Get Data for :  VUZI
# C:/Users/hansf/git/python/aktie/Python4Finance/VUZI.csv  Saved
# Finished
# Get Data for :  WTI
# C:/Users/hansf/git/python/aktie/Python4Finance/WTI.csv  Saved
# Finished
# Get Data for :  WPC
# C:/Users/hansf/git/python/aktie/Python4Finance/WPC.csv  Saved
# Finished
# Get Data for :  WRB
# C:/Users/hansf/git/python/aktie/Python4Finance/WRB.csv  Saved
# Finished
# Get Data for :  GRA
# - GRA: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/GRA.csv  Saved
# Finished
# Get Data for :  GWW
# C:/Users/hansf/git/python/aktie/Python4Finance/GWW.csv  Saved
# Finished
# Get Data for :  WNC
# C:/Users/hansf/git/python/aktie/Python4Finance/WNC.csv  Saved
# Finished
# Get Data for :  WBC
# - WBC: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/WBC.csv  Saved
# Finished
# Get Data for :  WDR
# - WDR: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/WDR.csv  Saved
# Finished
# Get Data for :  WTRH
# C:/Users/hansf/git/python/aktie/Python4Finance/WTRH.csv  Saved
# Finished
# Get Data for :  WBA
# C:/Users/hansf/git/python/aktie/Python4Finance/WBA.csv  Saved
# Finished
# Get Data for :  WD
# C:/Users/hansf/git/python/aktie/Python4Finance/WD.csv  Saved
# Finished
# Get Data for :  WMT
# C:/Users/hansf/git/python/aktie/Python4Finance/WMT.csv  Saved
# Finished
# Get Data for :  HCC
# C:/Users/hansf/git/python/aktie/Python4Finance/HCC.csv  Saved
# Finished
# Get Data for :  WAFD
# C:/Users/hansf/git/python/aktie/Python4Finance/WAFD.csv  Saved
# Finished
# Get Data for :  WPG
# - WPG: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/WPG.csv  Saved
# Finished
# Get Data for :  WRE
# C:/Users/hansf/git/python/aktie/Python4Finance/WRE.csv  Saved
# Finished
# Get Data for :  WASH
# C:/Users/hansf/git/python/aktie/Python4Finance/WASH.csv  Saved
# Finished
# Get Data for :  WM
# C:/Users/hansf/git/python/aktie/Python4Finance/WM.csv  Saved
# Finished
# Get Data for :  WAT
# C:/Users/hansf/git/python/aktie/Python4Finance/WAT.csv  Saved
# Finished
# Get Data for :  WSBF
# C:/Users/hansf/git/python/aktie/Python4Finance/WSBF.csv  Saved
# Finished
# Get Data for :  WSO
# C:/Users/hansf/git/python/aktie/Python4Finance/WSO.csv  Saved
# Finished
# Get Data for :  WTS
# C:/Users/hansf/git/python/aktie/Python4Finance/WTS.csv  Saved
# Finished
# Get Data for :  WVE
# C:/Users/hansf/git/python/aktie/Python4Finance/WVE.csv  Saved
# Finished
# Get Data for :  W
# C:/Users/hansf/git/python/aktie/Python4Finance/W.csv  Saved
# Finished
# Get Data for :  WSTG
# C:/Users/hansf/git/python/aktie/Python4Finance/WSTG.csv  Saved
# Finished
# Get Data for :  WDFC
# C:/Users/hansf/git/python/aktie/Python4Finance/WDFC.csv  Saved
# Finished
# Get Data for :  WBS
# C:/Users/hansf/git/python/aktie/Python4Finance/WBS.csv  Saved
# Finished
# Get Data for :  WEC
# C:/Users/hansf/git/python/aktie/Python4Finance/WEC.csv  Saved
# Finished
# Get Data for :  WRI
# - WRI: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/WRI.csv  Saved
# Finished
# Get Data for :  WMK
# C:/Users/hansf/git/python/aktie/Python4Finance/WMK.csv  Saved
# Finished
# Get Data for :  WBT
# C:/Users/hansf/git/python/aktie/Python4Finance/WBT.csv  Saved
# Finished
# Get Data for :  WCG
# - WCG: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/WCG.csv  Saved
# Finished
# Get Data for :  WEBK
# - WEBK: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/WEBK.csv  Saved
# Finished
# Get Data for :  WFC
# C:/Users/hansf/git/python/aktie/Python4Finance/WFC.csv  Saved
# Finished
# Get Data for :  WELL
# C:/Users/hansf/git/python/aktie/Python4Finance/WELL.csv  Saved
# Finished
# Get Data for :  WERN
# C:/Users/hansf/git/python/aktie/Python4Finance/WERN.csv  Saved
# Finished
# Get Data for :  WSBC
# C:/Users/hansf/git/python/aktie/Python4Finance/WSBC.csv  Saved
# Finished
# Get Data for :  WAIR
# - WAIR: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/WAIR.csv  Saved
# Finished
# Get Data for :  WCC
# C:/Users/hansf/git/python/aktie/Python4Finance/WCC.csv  Saved
# Finished
# Get Data for :  WTBA
# C:/Users/hansf/git/python/aktie/Python4Finance/WTBA.csv  Saved
# Finished
# Get Data for :  WST
# C:/Users/hansf/git/python/aktie/Python4Finance/WST.csv  Saved
# Finished
# Get Data for :  WABC
# C:/Users/hansf/git/python/aktie/Python4Finance/WABC.csv  Saved
# Finished
# Get Data for :  WSTL
# C:/Users/hansf/git/python/aktie/Python4Finance/WSTL.csv  Saved
# Finished
# Get Data for :  WAL
# C:/Users/hansf/git/python/aktie/Python4Finance/WAL.csv  Saved
# Finished
# Get Data for :  WMC
# C:/Users/hansf/git/python/aktie/Python4Finance/WMC.csv  Saved
# Finished
# Get Data for :  WDC
# C:/Users/hansf/git/python/aktie/Python4Finance/WDC.csv  Saved
# Finished
# Get Data for :  WNEB
# C:/Users/hansf/git/python/aktie/Python4Finance/WNEB.csv  Saved
# Finished
# Get Data for :  WAB
# C:/Users/hansf/git/python/aktie/Python4Finance/WAB.csv  Saved
# Finished
# Get Data for :  WLK
# C:/Users/hansf/git/python/aktie/Python4Finance/WLK.csv  Saved
# Finished
# Get Data for :  WRK
# C:/Users/hansf/git/python/aktie/Python4Finance/WRK.csv  Saved
# Finished
# Get Data for :  WWR
# C:/Users/hansf/git/python/aktie/Python4Finance/WWR.csv  Saved
# Finished
# Get Data for :  WHG
# C:/Users/hansf/git/python/aktie/Python4Finance/WHG.csv  Saved
# Finished
# Get Data for :  WEX
# C:/Users/hansf/git/python/aktie/Python4Finance/WEX.csv  Saved
# Finished
# Get Data for :  WEYS
# C:/Users/hansf/git/python/aktie/Python4Finance/WEYS.csv  Saved
# Finished
# Get Data for :  WY
# C:/Users/hansf/git/python/aktie/Python4Finance/WY.csv  Saved
# Finished
# Get Data for :  WHLR
# C:/Users/hansf/git/python/aktie/Python4Finance/WHLR.csv  Saved
# Finished
# Get Data for :  WHR
# C:/Users/hansf/git/python/aktie/Python4Finance/WHR.csv  Saved
# Finished
# Get Data for :  WTM
# C:/Users/hansf/git/python/aktie/Python4Finance/WTM.csv  Saved
# Finished
# Get Data for :  WSR
# C:/Users/hansf/git/python/aktie/Python4Finance/WSR.csv  Saved
# Finished
# Get Data for :  WLL
# C:/Users/hansf/git/python/aktie/Python4Finance/WLL.csv  Saved
# Finished
# Get Data for :  WOW
# C:/Users/hansf/git/python/aktie/Python4Finance/WOW.csv  Saved
# Finished
# Get Data for :  WYY
# C:/Users/hansf/git/python/aktie/Python4Finance/WYY.csv  Saved
# Finished
# Get Data for :  WHLM
# C:/Users/hansf/git/python/aktie/Python4Finance/WHLM.csv  Saved
# Finished
# Get Data for :  WVVI
# C:/Users/hansf/git/python/aktie/Python4Finance/WVVI.csv  Saved
# Finished
# Get Data for :  WLDN
# C:/Users/hansf/git/python/aktie/Python4Finance/WLDN.csv  Saved
# Finished
# Get Data for :  WLH
# - WLH: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/WLH.csv  Saved
# Finished
# Get Data for :  WSM
# C:/Users/hansf/git/python/aktie/Python4Finance/WSM.csv  Saved
# Finished
# Get Data for :  WLFC
# C:/Users/hansf/git/python/aktie/Python4Finance/WLFC.csv  Saved
# Finished
# Get Data for :  WLTW
# C:/Users/hansf/git/python/aktie/Python4Finance/WLTW.csv  Saved
# Finished
# Get Data for :  WSC
# C:/Users/hansf/git/python/aktie/Python4Finance/WSC.csv  Saved
# Finished
# Get Data for :  WING
# C:/Users/hansf/git/python/aktie/Python4Finance/WING.csv  Saved
# Finished
# Get Data for :  WINA
# C:/Users/hansf/git/python/aktie/Python4Finance/WINA.csv  Saved
# Finished
# Get Data for :  WGO
# C:/Users/hansf/git/python/aktie/Python4Finance/WGO.csv  Saved
# Finished
# Get Data for :  WTFC
# C:/Users/hansf/git/python/aktie/Python4Finance/WTFC.csv  Saved
# Finished
# Get Data for :  WTT
# C:/Users/hansf/git/python/aktie/Python4Finance/WTT.csv  Saved
# Finished
# Get Data for :  WETF
# C:/Users/hansf/git/python/aktie/Python4Finance/WETF.csv  Saved
# Finished
# Get Data for :  WWW
# C:/Users/hansf/git/python/aktie/Python4Finance/WWW.csv  Saved
# Finished
# Get Data for :  WWD
# C:/Users/hansf/git/python/aktie/Python4Finance/WWD.csv  Saved
# Finished
# Get Data for :  WDAY
# C:/Users/hansf/git/python/aktie/Python4Finance/WDAY.csv  Saved
# Finished
# Get Data for :  WKHS
# C:/Users/hansf/git/python/aktie/Python4Finance/WKHS.csv  Saved
# Finished
# Get Data for :  WK
# C:/Users/hansf/git/python/aktie/Python4Finance/WK.csv  Saved
# Finished
# Get Data for :  WRLD
# C:/Users/hansf/git/python/aktie/Python4Finance/WRLD.csv  Saved
# Finished
# Get Data for :  INT
# C:/Users/hansf/git/python/aktie/Python4Finance/INT.csv  Saved
# Finished
# Get Data for :  WWE
# C:/Users/hansf/git/python/aktie/Python4Finance/WWE.csv  Saved
# Finished
# Get Data for :  WOR
# C:/Users/hansf/git/python/aktie/Python4Finance/WOR.csv  Saved
# Finished
# Get Data for :  WPX
# - WPX: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/WPX.csv  Saved
# Finished
# Get Data for :  WRTC
# - WRTC: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/WRTC.csv  Saved
# Finished
# Get Data for :  WMGI
# - WMGI: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/WMGI.csv  Saved
# Finished
# Get Data for :  WSFS
# C:/Users/hansf/git/python/aktie/Python4Finance/WSFS.csv  Saved
# Finished
# Get Data for :  WVFC
# C:/Users/hansf/git/python/aktie/Python4Finance/WVFC.csv  Saved
# Finished
# Get Data for :  WW
# C:/Users/hansf/git/python/aktie/Python4Finance/WW.csv  Saved
# Finished
# Get Data for :  WYND
# - WYND: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/WYND.csv  Saved
# Finished
# Get Data for :  WH
# C:/Users/hansf/git/python/aktie/Python4Finance/WH.csv  Saved
# Finished
# Get Data for :  WYNN
# C:/Users/hansf/git/python/aktie/Python4Finance/WYNN.csv  Saved
# Finished
# Get Data for :  XFOR
# C:/Users/hansf/git/python/aktie/Python4Finance/XFOR.csv  Saved
# Finished
# Get Data for :  XBIT
# C:/Users/hansf/git/python/aktie/Python4Finance/XBIT.csv  Saved
# Finished
# Get Data for :  XELB
# C:/Users/hansf/git/python/aktie/Python4Finance/XELB.csv  Saved
# Finished
# Get Data for :  XEL
# C:/Users/hansf/git/python/aktie/Python4Finance/XEL.csv  Saved
# Finished
# Get Data for :  XNCR
# C:/Users/hansf/git/python/aktie/Python4Finance/XNCR.csv  Saved
# Finished
# Get Data for :  XHR
# C:/Users/hansf/git/python/aktie/Python4Finance/XHR.csv  Saved
# Finished
# Get Data for :  XERS
# C:/Users/hansf/git/python/aktie/Python4Finance/XERS.csv  Saved
# Finished
# Get Data for :  XRX
# C:/Users/hansf/git/python/aktie/Python4Finance/XRX.csv  Saved
# Finished
# Get Data for :  XLNX
# C:/Users/hansf/git/python/aktie/Python4Finance/XLNX.csv  Saved
# Finished
# Get Data for :  XOMA
# C:/Users/hansf/git/python/aktie/Python4Finance/XOMA.csv  Saved
# Finished
# Get Data for :  XPER
# C:/Users/hansf/git/python/aktie/Python4Finance/XPER.csv  Saved
# Finished
# Get Data for :  XPO
# C:/Users/hansf/git/python/aktie/Python4Finance/XPO.csv  Saved
# Finished
# Get Data for :  XSPA
# C:/Users/hansf/git/python/aktie/Python4Finance/XSPA.csv  Saved
# Finished
# Get Data for :  XTNT
# C:/Users/hansf/git/python/aktie/Python4Finance/XTNT.csv  Saved
# Finished
# Get Data for :  XYL
# C:/Users/hansf/git/python/aktie/Python4Finance/XYL.csv  Saved
# Finished
# Get Data for :  YELP
# C:/Users/hansf/git/python/aktie/Python4Finance/YELP.csv  Saved
# Finished
# Get Data for :  YETI
# C:/Users/hansf/git/python/aktie/Python4Finance/YETI.csv  Saved
# Finished
# Get Data for :  YEXT
# C:/Users/hansf/git/python/aktie/Python4Finance/YEXT.csv  Saved
# Finished
# Get Data for :  YTEN
# C:/Users/hansf/git/python/aktie/Python4Finance/YTEN.csv  Saved
# Finished
# Get Data for :  YMAB
# C:/Users/hansf/git/python/aktie/Python4Finance/YMAB.csv  Saved
# Finished
# Get Data for :  YORW
# C:/Users/hansf/git/python/aktie/Python4Finance/YORW.csv  Saved
# Finished
# Get Data for :  YRCW
# - YRCW: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/YRCW.csv  Saved
# Finished
# Get Data for :  YUM
# C:/Users/hansf/git/python/aktie/Python4Finance/YUM.csv  Saved
# Finished
# Get Data for :  YUMA
# - YUMA: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/YUMA.csv  Saved
# Finished
# Get Data for :  CTIB
# C:/Users/hansf/git/python/aktie/Python4Finance/CTIB.csv  Saved
# Finished
# Get Data for :  ZFGN
# - ZFGN: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/ZFGN.csv  Saved
# Finished
# Get Data for :  ZAGG
# - ZAGG: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/ZAGG.csv  Saved
# Finished
# Get Data for :  ZAYO
# - ZAYO: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/ZAYO.csv  Saved
# Finished
# Get Data for :  ZBRA
# C:/Users/hansf/git/python/aktie/Python4Finance/ZBRA.csv  Saved
# Finished
# Get Data for :  ZDGE
# C:/Users/hansf/git/python/aktie/Python4Finance/ZDGE.csv  Saved
# Finished
# Get Data for :  ZEN
# C:/Users/hansf/git/python/aktie/Python4Finance/ZEN.csv  Saved
# Finished
# Get Data for :  Z
# C:/Users/hansf/git/python/aktie/Python4Finance/Z.csv  Saved
# Finished
# Get Data for :  ZG
# C:/Users/hansf/git/python/aktie/Python4Finance/ZG.csv  Saved
# Finished
# Get Data for :  ZBH
# C:/Users/hansf/git/python/aktie/Python4Finance/ZBH.csv  Saved
# Finished
# Get Data for :  ZN
# - ZN: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/ZN.csv  Saved
# Finished
# Get Data for :  ZION
# C:/Users/hansf/git/python/aktie/Python4Finance/ZION.csv  Saved
# Finished
# Get Data for :  ZIOP
# C:/Users/hansf/git/python/aktie/Python4Finance/ZIOP.csv  Saved
# Finished
# Get Data for :  ZIXI
# C:/Users/hansf/git/python/aktie/Python4Finance/ZIXI.csv  Saved
# Finished
# Get Data for :  ZTS
# C:/Users/hansf/git/python/aktie/Python4Finance/ZTS.csv  Saved
# Finished
# Get Data for :  ZGNX
# C:/Users/hansf/git/python/aktie/Python4Finance/ZGNX.csv  Saved
# Finished
# Get Data for :  ZM
# C:/Users/hansf/git/python/aktie/Python4Finance/ZM.csv  Saved
# Finished
# Get Data for :  ZSAN
# C:/Users/hansf/git/python/aktie/Python4Finance/ZSAN.csv  Saved
# Finished
# Get Data for :  ZVO
# C:/Users/hansf/git/python/aktie/Python4Finance/ZVO.csv  Saved
# Finished
# Get Data for :  ZS
# C:/Users/hansf/git/python/aktie/Python4Finance/ZS.csv  Saved
# Finished
# Get Data for :  ZUMZ
# C:/Users/hansf/git/python/aktie/Python4Finance/ZUMZ.csv  Saved
# Finished
# Get Data for :  ZUO
# C:/Users/hansf/git/python/aktie/Python4Finance/ZUO.csv  Saved
# Finished
# Get Data for :  ZYNE
# C:/Users/hansf/git/python/aktie/Python4Finance/ZYNE.csv  Saved
# Finished
# Get Data for :  ZYXI
# C:/Users/hansf/git/python/aktie/Python4Finance/ZYXI.csv  Saved
# Finished
# Get Data for :  ZNGA
# C:/Users/hansf/git/python/aktie/Python4Finance/ZNGA.csv  Saved
# Finished
