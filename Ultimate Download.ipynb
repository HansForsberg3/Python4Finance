# %%
# Provides ways to work with large multidimensional arrays
import numpy as np 
# Allows for further data manipulation and analysis
import pandas as pd 
import matplotlib.pyplot as plt # Plotting
import matplotlib.dates as mdates # Styling dates
# %matplotlib inline

# pip install numpy
# conda install -c anaconda pandas
# conda install -c conda-forge matplotlib

import datetime as dt # For defining dates

import time

# In Powershell Prompt : conda install -c conda-forge multitasking
# pip install -i https://pypi.anaconda.org/ranaroussi/simple yfinance

import yfinance as yf

# To show all your output File -> Preferences -> Settings Search for Notebook
# Notebook Output Text Line Limit and set to 100

# Used for file handling like deleting files
import os

# conda install -c conda-forge cufflinks-py
# conda install -c plotly plotly
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()

from plotly.subplots import make_subplots

# New Imports
# Used to get data from a directory
import os
from os import listdir
from os.path import isfile, join

import warnings
warnings.simplefilter("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Constants

# %%
PATH = "C:/Users/hansf/git/python/aktie/Python4Finance/stocks/"

# Start end date defaults
S_DATE = "2017-02-01"
E_DATE = "2022-12-18"
S_DATE_DT = pd.to_datetime(S_DATE)
E_DATE_DT = pd.to_datetime(E_DATE)

# %% [markdown]
# ## Get Column Data from CSV

# %%
def get_column_from_csv(file, col_name):
    # Try to get the file and if it doesn't exist issue a warning
    try:
        df = pd.read_csv(file)
    except FileNotFoundError:
        print("File Doesn't Exist")
    else:
        return df[col_name]

# %% [markdown]
# ## Get Stock Tickers

# %%
tickers = get_column_from_csv("C:/Users/hansf/git/python/aktie/Python4Finance/big_stock_sectors.csv","Ticker")
print(len(tickers))
# Out:
# 6103

# %% [markdown]
# ## Save Stock Data to CSV

# %%
# Function that gets a dataframe by providing a ticker and starting date
def save_to_csv_from_yahoo(folder, ticker):
    stock = yf.Ticker(ticker)
    
    try:
        print("Get Data for : ", ticker)
        # Get historical closing price data
        df = stock.history(period="5y")
    
        # Wait 2 seconds
        time.sleep(2)
        
        # Remove the period for saving the file name
        # Save data to a CSV file
        # File to save to 
        the_file = folder + ticker.replace(".", "_") + '.csv'
        print(the_file, " Saved")
        df.to_csv(the_file)
    except Exception as ex:
        print("Couldn't Get Data for :", ticker)

# %% [markdown]
# ## Download All Stocks

# %%
for x in range( 3481, 6103):
    save_to_csv_from_yahoo(PATH, tickers[x])
    print("Finished")
# Out:
# Get Data for :  MFG
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MFG.csv  Saved
# Finished
# Get Data for :  MFGP
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MFGP.csv  Saved
# Finished
# Get Data for :  MFH
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MFH.csv  Saved
# Finished
# Get Data for :  MFIN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MFIN.csv  Saved
# Finished
# Get Data for :  MG
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MG.csv  Saved
# Finished
# Get Data for :  MGA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MGA.csv  Saved
# Finished
# Get Data for :  MGEE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MGEE.csv  Saved
# Finished
# Get Data for :  MGI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MGI.csv  Saved
# Finished
# Get Data for :  MGIC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MGIC.csv  Saved
# Finished
# Get Data for :  MGLN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MGLN.csv  Saved
# Finished
# Get Data for :  MGM
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MGM.csv  Saved
# Finished
# Get Data for :  MGNI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MGNI.csv  Saved
# Finished
# Get Data for :  MGNX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MGNX.csv  Saved
# Finished
# Get Data for :  MGP
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MGP.csv  Saved
# Finished
# Get Data for :  MGPI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MGPI.csv  Saved
# Finished
# Get Data for :  MGRC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MGRC.csv  Saved
# Finished
# Get Data for :  MGTA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MGTA.csv  Saved
# Finished
# Get Data for :  MGTX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MGTX.csv  Saved
# Finished
# Get Data for :  MGY
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MGY.csv  Saved
# Finished
# Get Data for :  MGYR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MGYR.csv  Saved
# Finished
# Get Data for :  MHH
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MHH.csv  Saved
# Finished
# Get Data for :  MHK
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MHK.csv  Saved
# Finished
# Get Data for :  MHLD
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MHLD.csv  Saved
# Finished
# Get Data for :  MHO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MHO.csv  Saved
# Finished
# Get Data for :  MIC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MIC.csv  Saved
# Finished
# Get Data for :  MICT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MICT.csv  Saved
# Finished
# Get Data for :  MIDD
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MIDD.csv  Saved
# Finished
# Get Data for :  MIGI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MIGI.csv  Saved
# Finished
# Get Data for :  MILE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MILE.csv  Saved
# Finished
# Get Data for :  MIME
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MIME.csv  Saved
# Finished
# Get Data for :  MIMO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MIMO.csv  Saved
# Finished
# Get Data for :  MIND
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MIND.csv  Saved
# Finished
# Get Data for :  MINM
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MINM.csv  Saved
# Finished
# Get Data for :  MIR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MIR.csv  Saved
# Finished
# Get Data for :  MIRM
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MIRM.csv  Saved
# Finished
# Get Data for :  MIRO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MIRO.csv  Saved
# Finished
# Get Data for :  MIST
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MIST.csv  Saved
# Finished
# Get Data for :  MIT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MIT.csv  Saved
# Finished
# Get Data for :  MITA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MITA.csv  Saved
# Finished
# Get Data for :  MITC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MITC.csv  Saved
# Finished
# Get Data for :  MITK
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MITK.csv  Saved
# Finished
# Get Data for :  MITO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MITO.csv  Saved
# Finished
# Get Data for :  MITQ
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MITQ.csv  Saved
# Finished
# Get Data for :  MITT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MITT.csv  Saved
# Finished
# Get Data for :  MIXT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MIXT.csv  Saved
# Finished
# Get Data for :  MKC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MKC.csv  Saved
# Finished
# Get Data for :  MKD
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MKD.csv  Saved
# Finished
# Get Data for :  MKFG
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MKFG.csv  Saved
# Finished
# Get Data for :  MKL
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MKL.csv  Saved
# Finished
# Get Data for :  MKSI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MKSI.csv  Saved
# Finished
# Get Data for :  MKTW
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MKTW.csv  Saved
# Finished
# Get Data for :  MKTX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MKTX.csv  Saved
# Finished
# Get Data for :  ML
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ML.csv  Saved
# Finished
# Get Data for :  MLAB
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MLAB.csv  Saved
# Finished
# Get Data for :  MLAC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MLAC.csv  Saved
# Finished
# Get Data for :  MLAI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MLAI.csv  Saved
# Finished
# Get Data for :  MLCO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MLCO.csv  Saved
# Finished
# Get Data for :  MLI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MLI.csv  Saved
# Finished
# Get Data for :  MLKN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MLKN.csv  Saved
# Finished
# Get Data for :  MLM
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MLM.csv  Saved
# Finished
# Get Data for :  MLNK
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MLNK.csv  Saved
# Finished
# Get Data for :  MLP
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MLP.csv  Saved
# Finished
# Get Data for :  MLR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MLR.csv  Saved
# Finished
# Get Data for :  MLSS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MLSS.csv  Saved
# Finished
# Get Data for :  MLVF
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MLVF.csv  Saved
# Finished
# Get Data for :  MMAT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MMAT.csv  Saved
# Finished
# Get Data for :  MMC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MMC.csv  Saved
# Finished
# Get Data for :  MMI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MMI.csv  Saved
# Finished
# Get Data for :  MMLP
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MMLP.csv  Saved
# Finished
# Get Data for :  MMM
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MMM.csv  Saved
# Finished
# Get Data for :  MMMB
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MMMB.csv  Saved
# Finished
# Get Data for :  MMP
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MMP.csv  Saved
# Finished
# Get Data for :  MMS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MMS.csv  Saved
# Finished
# Get Data for :  MMSI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MMSI.csv  Saved
# Finished
# Get Data for :  MMX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MMX.csv  Saved
# Finished
# Get Data for :  MMYT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MMYT.csv  Saved
# Finished
# Get Data for :  MN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MN.csv  Saved
# Finished
# Get Data for :  MNDO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MNDO.csv  Saved
# Finished
# Get Data for :  MNDT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MNDT.csv  Saved
# Finished
# Get Data for :  MNDY
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MNDY.csv  Saved
# Finished
# Get Data for :  MNKD
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MNKD.csv  Saved
# Finished
# Get Data for :  MNMD
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MNMD.csv  Saved
# Finished
# Get Data for :  MNOV
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MNOV.csv  Saved
# Finished
# Get Data for :  MNPR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MNPR.csv  Saved
# Finished
# Get Data for :  MNR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MNR.csv  Saved
# Finished
# Get Data for :  MNRL
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MNRL.csv  Saved
# Finished
# Get Data for :  MNRO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MNRO.csv  Saved
# Finished
# Get Data for :  MNSB
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MNSB.csv  Saved
# Finished
# Get Data for :  MNSO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MNSO.csv  Saved
# Finished
# Get Data for :  MNST
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MNST.csv  Saved
# Finished
# Get Data for :  MNTK
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MNTK.csv  Saved
# Finished
# Get Data for :  MNTS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MNTS.csv  Saved
# Finished
# Get Data for :  MNTV
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MNTV.csv  Saved
# Finished
# Get Data for :  MNTX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MNTX.csv  Saved
# Finished
# Get Data for :  MO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MO.csv  Saved
# Finished
# Get Data for :  MOBQ
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MOBQ.csv  Saved
# Finished
# Get Data for :  MOD
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MOD.csv  Saved
# Finished
# Get Data for :  MODN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MODN.csv  Saved
# Finished
# Get Data for :  MODV
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MODV.csv  Saved
# Finished
# Get Data for :  MOFG
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MOFG.csv  Saved
# Finished
# Get Data for :  MOG.A
# - MOG.A: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MOG_A.csv  Saved
# Finished
# Get Data for :  MOG.B
# - MOG.B: No data found, symbol may be delisted
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MOG_B.csv  Saved
# Finished
# Get Data for :  MOGO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MOGO.csv  Saved
# Finished
# Get Data for :  MOGU
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MOGU.csv  Saved
# Finished
# Get Data for :  MOH
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MOH.csv  Saved
# Finished
# Get Data for :  MOHO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MOHO.csv  Saved
# Finished
# Get Data for :  MOLN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MOLN.csv  Saved
# Finished
# Get Data for :  MOMO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MOMO.csv  Saved
# Finished
# Get Data for :  MON
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MON.csv  Saved
# Finished
# Get Data for :  MOR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MOR.csv  Saved
# Finished
# Get Data for :  MORF
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MORF.csv  Saved
# Finished
# Get Data for :  MORN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MORN.csv  Saved
# Finished
# Get Data for :  MOS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MOS.csv  Saved
# Finished
# Get Data for :  MOTS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MOTS.csv  Saved
# Finished
# Get Data for :  MOTV
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MOTV.csv  Saved
# Finished
# Get Data for :  MOV
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MOV.csv  Saved
# Finished
# Get Data for :  MOVE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MOVE.csv  Saved
# Finished
# Get Data for :  MOXC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MOXC.csv  Saved
# Finished
# Get Data for :  MP
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MP.csv  Saved
# Finished
# Get Data for :  MPAA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MPAA.csv  Saved
# Finished
# Get Data for :  MPAC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MPAC.csv  Saved
# Finished
# Get Data for :  MPB
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MPB.csv  Saved
# Finished
# Get Data for :  MPC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MPC.csv  Saved
# Finished
# Get Data for :  MPLN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MPLN.csv  Saved
# Finished
# Get Data for :  MPLX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MPLX.csv  Saved
# Finished
# Get Data for :  MPW
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MPW.csv  Saved
# Finished
# Get Data for :  MPWR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MPWR.csv  Saved
# Finished
# Get Data for :  MPX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MPX.csv  Saved
# Finished
# Get Data for :  MQ
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MQ.csv  Saved
# Finished
# Get Data for :  MRAI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MRAI.csv  Saved
# Finished
# Get Data for :  MRAM
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MRAM.csv  Saved
# Finished
# Get Data for :  MRBK
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MRBK.csv  Saved
# Finished
# Get Data for :  MRC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MRC.csv  Saved
# Finished
# Get Data for :  MRCC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MRCC.csv  Saved
# Finished
# Get Data for :  MRCY
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MRCY.csv  Saved
# Finished
# Get Data for :  MREO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MREO.csv  Saved
# Finished
# Get Data for :  MRIN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MRIN.csv  Saved
# Finished
# Get Data for :  MRK
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MRK.csv  Saved
# Finished
# Get Data for :  MRKR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MRKR.csv  Saved
# Finished
# Get Data for :  MRLN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MRLN.csv  Saved
# Finished
# Get Data for :  MRM
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MRM.csv  Saved
# Finished
# Get Data for :  MRNA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MRNA.csv  Saved
# Finished
# Get Data for :  MRNS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MRNS.csv  Saved
# Finished
# Get Data for :  MRO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MRO.csv  Saved
# Finished
# Get Data for :  MRSN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MRSN.csv  Saved
# Finished
# Get Data for :  MRTN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MRTN.csv  Saved
# Finished
# Get Data for :  MRTX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MRTX.csv  Saved
# Finished
# Get Data for :  MRUS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MRUS.csv  Saved
# Finished
# Get Data for :  MRVI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MRVI.csv  Saved
# Finished
# Get Data for :  MRVL
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MRVL.csv  Saved
# Finished
# Get Data for :  MS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MS.csv  Saved
# Finished
# Get Data for :  MSA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MSA.csv  Saved
# Finished
# Get Data for :  MSAC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MSAC.csv  Saved
# Finished
# Get Data for :  MSB
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MSB.csv  Saved
# Finished
# Get Data for :  MSBI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MSBI.csv  Saved
# Finished
# Get Data for :  MSC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MSC.csv  Saved
# Finished
# Get Data for :  MSCI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MSCI.csv  Saved
# Finished
# Get Data for :  MSDA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MSDA.csv  Saved
# Finished
# Get Data for :  MSEX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MSEX.csv  Saved
# Finished
# Get Data for :  MSFT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MSFT.csv  Saved
# Finished
# Get Data for :  MSGE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MSGE.csv  Saved
# Finished
# Get Data for :  MSGM
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MSGM.csv  Saved
# Finished
# Get Data for :  MSGS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MSGS.csv  Saved
# Finished
# Get Data for :  MSI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MSI.csv  Saved
# Finished
# Get Data for :  MSM
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MSM.csv  Saved
# Finished
# Get Data for :  MSN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MSN.csv  Saved
# Finished
# Get Data for :  MSP
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MSP.csv  Saved
# Finished
# Get Data for :  MSTR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MSTR.csv  Saved
# Finished
# Get Data for :  MSVB
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MSVB.csv  Saved
# Finished
# Get Data for :  MT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MT.csv  Saved
# Finished
# Get Data for :  MTA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MTA.csv  Saved
# Finished
# Get Data for :  MTAC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MTAC.csv  Saved
# Finished
# Get Data for :  MTAL
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MTAL.csv  Saved
# Finished
# Get Data for :  MTB
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MTB.csv  Saved
# Finished
# Get Data for :  MTBC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MTBC.csv  Saved
# Finished
# Get Data for :  MTC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MTC.csv  Saved
# Finished
# Get Data for :  MTCH
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MTCH.csv  Saved
# Finished
# Get Data for :  MTCR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MTCR.csv  Saved
# Finished
# Get Data for :  MTD
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MTD.csv  Saved
# Finished
# Get Data for :  MTDR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MTDR.csv  Saved
# Finished
# Get Data for :  MTEM
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MTEM.csv  Saved
# Finished
# Get Data for :  MTEX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MTEX.csv  Saved
# Finished
# Get Data for :  MTG
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MTG.csv  Saved
# Finished
# Get Data for :  MTH
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MTH.csv  Saved
# Finished
# Get Data for :  MTL
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MTL.csv  Saved
# Finished
# Get Data for :  MTLS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MTLS.csv  Saved
# Finished
# Get Data for :  MTN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MTN.csv  Saved
# Finished
# Get Data for :  MTNB
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MTNB.csv  Saved
# Finished
# Get Data for :  MTOR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MTOR.csv  Saved
# Finished
# Get Data for :  MTP
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MTP.csv  Saved
# Finished
# Get Data for :  MTR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MTR.csv  Saved
# Finished
# Get Data for :  MTRN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MTRN.csv  Saved
# Finished
# Get Data for :  MTRX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MTRX.csv  Saved
# Finished
# Get Data for :  MTRY
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MTRY.csv  Saved
# Finished
# Get Data for :  MTSI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MTSI.csv  Saved
# Finished
# Get Data for :  MTTR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MTTR.csv  Saved
# Finished
# Get Data for :  MTW
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MTW.csv  Saved
# Finished
# Get Data for :  MTX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MTX.csv  Saved
# Finished
# Get Data for :  MTZ
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MTZ.csv  Saved
# Finished
# Get Data for :  MU
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MU.csv  Saved
# Finished
# Get Data for :  MUDS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MUDS.csv  Saved
# Finished
# Get Data for :  MUFG
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MUFG.csv  Saved
# Finished
# Get Data for :  MULN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MULN.csv  Saved
# Finished
# Get Data for :  MUR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MUR.csv  Saved
# Finished
# Get Data for :  MUSA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MUSA.csv  Saved
# Finished
# Get Data for :  MUX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MUX.csv  Saved
# Finished
# Get Data for :  MVBF
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MVBF.csv  Saved
# Finished
# Get Data for :  MVIS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MVIS.csv  Saved
# Finished
# Get Data for :  MVST
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MVST.csv  Saved
# Finished
# Get Data for :  MWA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MWA.csv  Saved
# Finished
# Get Data for :  MX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MX.csv  Saved
# Finished
# Get Data for :  MXC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MXC.csv  Saved
# Finished
# Get Data for :  MXCT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MXCT.csv  Saved
# Finished
# Get Data for :  MXL
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MXL.csv  Saved
# Finished
# Get Data for :  MYE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MYE.csv  Saved
# Finished
# Get Data for :  MYFW
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MYFW.csv  Saved
# Finished
# Get Data for :  MYGN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MYGN.csv  Saved
# Finished
# Get Data for :  MYMD
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MYMD.csv  Saved
# Finished
# Get Data for :  MYNA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MYNA.csv  Saved
# Finished
# Get Data for :  MYNZ
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MYNZ.csv  Saved
# Finished
# Get Data for :  MYO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MYO.csv  Saved
# Finished
# Get Data for :  MYOV
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MYOV.csv  Saved
# Finished
# Get Data for :  MYPS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MYPS.csv  Saved
# Finished
# Get Data for :  MYRG
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MYRG.csv  Saved
# Finished
# Get Data for :  MYSZ
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MYSZ.csv  Saved
# Finished
# Get Data for :  MYTE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/MYTE.csv  Saved
# Finished
# Get Data for :  NAAC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NAAC.csv  Saved
# Finished
# Get Data for :  NABL
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NABL.csv  Saved
# Finished
# Get Data for :  NAII
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NAII.csv  Saved
# Finished
# Get Data for :  NAK
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NAK.csv  Saved
# Finished
# Get Data for :  NAKD
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NAKD.csv  Saved
# Finished
# Get Data for :  NAOV
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NAOV.csv  Saved
# Finished
# Get Data for :  NAPA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NAPA.csv  Saved
# Finished
# Get Data for :  NARI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NARI.csv  Saved
# Finished
# Get Data for :  NAT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NAT.csv  Saved
# Finished
# Get Data for :  NATH
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NATH.csv  Saved
# Finished
# Get Data for :  NATI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NATI.csv  Saved
# Finished
# Get Data for :  NATR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NATR.csv  Saved
# Finished
# Get Data for :  NAUT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NAUT.csv  Saved
# Finished
# Get Data for :  NAVB
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NAVB.csv  Saved
# Finished
# Get Data for :  NAVI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NAVI.csv  Saved
# Finished
# Get Data for :  NBEV
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NBEV.csv  Saved
# Finished
# Get Data for :  NBHC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NBHC.csv  Saved
# Finished
# Get Data for :  NBIX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NBIX.csv  Saved
# Finished
# Get Data for :  NBN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NBN.csv  Saved
# Finished
# Get Data for :  NBR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NBR.csv  Saved
# Finished
# Get Data for :  NBRV
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NBRV.csv  Saved
# Finished
# Get Data for :  NBSE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NBSE.csv  Saved
# Finished
# Get Data for :  NBST
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NBST.csv  Saved
# Finished
# Get Data for :  NBTB
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NBTB.csv  Saved
# Finished
# Get Data for :  NBTX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NBTX.csv  Saved
# Finished
# Get Data for :  NBY
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NBY.csv  Saved
# Finished
# Get Data for :  NC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NC.csv  Saved
# Finished
# Get Data for :  NCAC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NCAC.csv  Saved
# Finished
# Get Data for :  NCBS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NCBS.csv  Saved
# Finished
# Get Data for :  NCLH
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NCLH.csv  Saved
# Finished
# Get Data for :  NCMI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NCMI.csv  Saved
# Finished
# Get Data for :  NCNA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NCNA.csv  Saved
# Finished
# Get Data for :  NCNO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NCNO.csv  Saved
# Finished
# Get Data for :  NCR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NCR.csv  Saved
# Finished
# Get Data for :  NCSM
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NCSM.csv  Saved
# Finished
# Get Data for :  NCTY
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NCTY.csv  Saved
# Finished
# Get Data for :  NDAC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NDAC.csv  Saved
# Finished
# Get Data for :  NDAQ
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NDAQ.csv  Saved
# Finished
# Get Data for :  NDLS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NDLS.csv  Saved
# Finished
# Get Data for :  NDRA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NDRA.csv  Saved
# Finished
# Get Data for :  NDSN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NDSN.csv  Saved
# Finished
# Get Data for :  NE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NE.csv  Saved
# Finished
# Get Data for :  NECB
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NECB.csv  Saved
# Finished
# Get Data for :  NEE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NEE.csv  Saved
# Finished
# Get Data for :  NEGG
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NEGG.csv  Saved
# Finished
# Get Data for :  NEM
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NEM.csv  Saved
# Finished
# Get Data for :  NEN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NEN.csv  Saved
# Finished
# Get Data for :  NEO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NEO.csv  Saved
# Finished
# Get Data for :  NEOG
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NEOG.csv  Saved
# Finished
# Get Data for :  NEON
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NEON.csv  Saved
# Finished
# Get Data for :  NEP
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NEP.csv  Saved
# Finished
# Get Data for :  NEPH
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NEPH.csv  Saved
# Finished
# Get Data for :  NEPT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NEPT.csv  Saved
# Finished
# Get Data for :  NERV
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NERV.csv  Saved
# Finished
# Get Data for :  NES
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NES.csv  Saved
# Finished
# Get Data for :  NESR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NESR.csv  Saved
# Finished
# Get Data for :  NET
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NET.csv  Saved
# Finished
# Get Data for :  NETI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NETI.csv  Saved
# Finished
# Get Data for :  NEU
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NEU.csv  Saved
# Finished
# Get Data for :  NEW
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NEW.csv  Saved
# Finished
# Get Data for :  NEWP
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NEWP.csv  Saved
# Finished
# Get Data for :  NEWR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NEWR.csv  Saved
# Finished
# Get Data for :  NEWT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NEWT.csv  Saved
# Finished
# Get Data for :  NEX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NEX.csv  Saved
# Finished
# Get Data for :  NEXA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NEXA.csv  Saved
# Finished
# Get Data for :  NEXI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NEXI.csv  Saved
# Finished
# Get Data for :  NEXT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NEXT.csv  Saved
# Finished
# Get Data for :  NFBK
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NFBK.csv  Saved
# Finished
# Get Data for :  NFE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NFE.csv  Saved
# Finished
# Get Data for :  NFG
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NFG.csv  Saved
# Finished
# Get Data for :  NFGC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NFGC.csv  Saved
# Finished
# Get Data for :  NFH
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NFH.csv  Saved
# Finished
# Get Data for :  NFLX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NFLX.csv  Saved
# Finished
# Get Data for :  NFYS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NFYS.csv  Saved
# Finished
# Get Data for :  NG
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NG.csv  Saved
# Finished
# Get Data for :  NGC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NGC.csv  Saved
# Finished
# Get Data for :  NGD
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NGD.csv  Saved
# Finished
# Get Data for :  NGG
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NGG.csv  Saved
# Finished
# Get Data for :  NGL
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NGL.csv  Saved
# Finished
# Get Data for :  NGM
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NGM.csv  Saved
# Finished
# Get Data for :  NGMS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NGMS.csv  Saved
# Finished
# Get Data for :  NGS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NGS.csv  Saved
# Finished
# Get Data for :  NGVC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NGVC.csv  Saved
# Finished
# Get Data for :  NGVT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NGVT.csv  Saved
# Finished
# Get Data for :  NH
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NH.csv  Saved
# Finished
# Get Data for :  NHC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NHC.csv  Saved
# Finished
# Get Data for :  NHI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NHI.csv  Saved
# Finished
# Get Data for :  NHTC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NHTC.csv  Saved
# Finished
# Get Data for :  NI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NI.csv  Saved
# Finished
# Get Data for :  NICE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NICE.csv  Saved
# Finished
# Get Data for :  NICK
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NICK.csv  Saved
# Finished
# Get Data for :  NILE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NILE.csv  Saved
# Finished
# Get Data for :  NINE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NINE.csv  Saved
# Finished
# Get Data for :  NIO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NIO.csv  Saved
# Finished
# Get Data for :  NISN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NISN.csv  Saved
# Finished
# Get Data for :  NIU
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NIU.csv  Saved
# Finished
# Get Data for :  NJR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NJR.csv  Saved
# Finished
# Get Data for :  NKE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NKE.csv  Saved
# Finished
# Get Data for :  NKLA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NKLA.csv  Saved
# Finished
# Get Data for :  NKSH
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NKSH.csv  Saved
# Finished
# Get Data for :  NKTR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NKTR.csv  Saved
# Finished
# Get Data for :  NKTX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NKTX.csv  Saved
# Finished
# Get Data for :  NL
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NL.csv  Saved
# Finished
# Get Data for :  NLIT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NLIT.csv  Saved
# Finished
# Get Data for :  NLOK
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NLOK.csv  Saved
# Finished
# Get Data for :  NLS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NLS.csv  Saved
# Finished
# Get Data for :  NLSN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NLSN.csv  Saved
# Finished
# Get Data for :  NLSP
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NLSP.csv  Saved
# Finished
# Get Data for :  NLTX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NLTX.csv  Saved
# Finished
# Get Data for :  NLY
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NLY.csv  Saved
# Finished
# Get Data for :  NM
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NM.csv  Saved
# Finished
# Get Data for :  NMFC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NMFC.csv  Saved
# Finished
# Get Data for :  NMG
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NMG.csv  Saved
# Finished
# Get Data for :  NMIH
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NMIH.csv  Saved
# Finished
# Get Data for :  NMM
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NMM.csv  Saved
# Finished
# Get Data for :  NMMC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NMMC.csv  Saved
# Finished
# Get Data for :  NMR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NMR.csv  Saved
# Finished
# Get Data for :  NMRD
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NMRD.csv  Saved
# Finished
# Get Data for :  NMRK
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NMRK.csv  Saved
# Finished
# Get Data for :  NMTC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NMTC.csv  Saved
# Finished
# Get Data for :  NMTR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NMTR.csv  Saved
# Finished
# Get Data for :  NN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NN.csv  Saved
# Finished
# Get Data for :  NNBR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NNBR.csv  Saved
# Finished
# Get Data for :  NNDM
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NNDM.csv  Saved
# Finished
# Get Data for :  NNI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NNI.csv  Saved
# Finished
# Get Data for :  NNN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NNN.csv  Saved
# Finished
# Get Data for :  NNOX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NNOX.csv  Saved
# Finished
# Get Data for :  NNVC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NNVC.csv  Saved
# Finished
# Get Data for :  NOA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NOA.csv  Saved
# Finished
# Get Data for :  NOAC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NOAC.csv  Saved
# Finished
# Get Data for :  NOAH
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NOAH.csv  Saved
# Finished
# Get Data for :  NOC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NOC.csv  Saved
# Finished
# Get Data for :  NODK
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NODK.csv  Saved
# Finished
# Get Data for :  NOG
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NOG.csv  Saved
# Finished
# Get Data for :  NOK
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NOK.csv  Saved
# Finished
# Get Data for :  NOMD
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NOMD.csv  Saved
# Finished
# Get Data for :  NOTV
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NOTV.csv  Saved
# Finished
# Get Data for :  NOV
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NOV.csv  Saved
# Finished
# Get Data for :  NOVA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NOVA.csv  Saved
# Finished
# Get Data for :  NOVN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NOVN.csv  Saved
# Finished
# Get Data for :  NOVT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NOVT.csv  Saved
# Finished
# Get Data for :  NOVV
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NOVV.csv  Saved
# Finished
# Get Data for :  NOW
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NOW.csv  Saved
# Finished
# Get Data for :  NP
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NP.csv  Saved
# Finished
# Get Data for :  NPCE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NPCE.csv  Saved
# Finished
# Get Data for :  NPK
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NPK.csv  Saved
# Finished
# Get Data for :  NPO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NPO.csv  Saved
# Finished
# Get Data for :  NPTN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NPTN.csv  Saved
# Finished
# Get Data for :  NR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NR.csv  Saved
# Finished
# Get Data for :  NRAC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NRAC.csv  Saved
# Finished
# Get Data for :  NRBO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NRBO.csv  Saved
# Finished
# Get Data for :  NRC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NRC.csv  Saved
# Finished
# Get Data for :  NRDS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NRDS.csv  Saved
# Finished
# Get Data for :  NRDY
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NRDY.csv  Saved
# Finished
# Get Data for :  NREF
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NREF.csv  Saved
# Finished
# Get Data for :  NRG
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NRG.csv  Saved
# Finished
# Get Data for :  NRIM
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NRIM.csv  Saved
# Finished
# Get Data for :  NRIX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NRIX.csv  Saved
# Finished
# Get Data for :  NRP
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NRP.csv  Saved
# Finished
# Get Data for :  NRSN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NRSN.csv  Saved
# Finished
# Get Data for :  NRT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NRT.csv  Saved
# Finished
# Get Data for :  NRXP
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NRXP.csv  Saved
# Finished
# Get Data for :  NRZ
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NRZ.csv  Saved
# Finished
# Get Data for :  NS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NS.csv  Saved
# Finished
# Get Data for :  NSA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NSA.csv  Saved
# Finished
# Get Data for :  NSC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NSC.csv  Saved
# Finished
# Get Data for :  NSEC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NSEC.csv  Saved
# Finished
# Get Data for :  NSIT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NSIT.csv  Saved
# Finished
# Get Data for :  NSP
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NSP.csv  Saved
# Finished
# Get Data for :  NSPR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NSPR.csv  Saved
# Finished
# Get Data for :  NSR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NSR.csv  Saved
# Finished
# Get Data for :  NSSC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NSSC.csv  Saved
# Finished
# Get Data for :  NSTB
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NSTB.csv  Saved
# Finished
# Get Data for :  NSTC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NSTC.csv  Saved
# Finished
# Get Data for :  NSTD
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NSTD.csv  Saved
# Finished
# Get Data for :  NSTG
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NSTG.csv  Saved
# Finished
# Get Data for :  NSYS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NSYS.csv  Saved
# Finished
# Get Data for :  NTAP
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NTAP.csv  Saved
# Finished
# Get Data for :  NTB
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NTB.csv  Saved
# Finished
# Get Data for :  NTCO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NTCO.csv  Saved
# Finished
# Get Data for :  NTCT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NTCT.csv  Saved
# Finished
# Get Data for :  NTES
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NTES.csv  Saved
# Finished
# Get Data for :  NTGR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NTGR.csv  Saved
# Finished
# Get Data for :  NTIC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NTIC.csv  Saved
# Finished
# Get Data for :  NTIP
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NTIP.csv  Saved
# Finished
# Get Data for :  NTLA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NTLA.csv  Saved
# Finished
# Get Data for :  NTNX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NTNX.csv  Saved
# Finished
# Get Data for :  NTP
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NTP.csv  Saved
# Finished
# Get Data for :  NTR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NTR.csv  Saved
# Finished
# Get Data for :  NTRA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NTRA.csv  Saved
# Finished
# Get Data for :  NTRB
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NTRB.csv  Saved
# Finished
# Get Data for :  NTRS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NTRS.csv  Saved
# Finished
# Get Data for :  NTST
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NTST.csv  Saved
# Finished
# Get Data for :  NTUS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NTUS.csv  Saved
# Finished
# Get Data for :  NTWK
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NTWK.csv  Saved
# Finished
# Get Data for :  NTZ
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NTZ.csv  Saved
# Finished
# Get Data for :  NU
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NU.csv  Saved
# Finished
# Get Data for :  NUAN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NUAN.csv  Saved
# Finished
# Get Data for :  NUE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NUE.csv  Saved
# Finished
# Get Data for :  NURO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NURO.csv  Saved
# Finished
# Get Data for :  NUS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NUS.csv  Saved
# Finished
# Get Data for :  NUVA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NUVA.csv  Saved
# Finished
# Get Data for :  NUVB
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NUVB.csv  Saved
# Finished
# Get Data for :  NUVL
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NUVL.csv  Saved
# Finished
# Get Data for :  NUWE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NUWE.csv  Saved
# Finished
# Get Data for :  NUZE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NUZE.csv  Saved
# Finished
# Get Data for :  NVAX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NVAX.csv  Saved
# Finished
# Get Data for :  NVCN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NVCN.csv  Saved
# Finished
# Get Data for :  NVCR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NVCR.csv  Saved
# Finished
# Get Data for :  NVDA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NVDA.csv  Saved
# Finished
# Get Data for :  NVEC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NVEC.csv  Saved
# Finished
# Get Data for :  NVEE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NVEE.csv  Saved
# Finished
# Get Data for :  NVEI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NVEI.csv  Saved
# Finished
# Get Data for :  NVFY
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NVFY.csv  Saved
# Finished
# Get Data for :  NVGS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NVGS.csv  Saved
# Finished
# Get Data for :  NVIV
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NVIV.csv  Saved
# Finished
# Get Data for :  NVMI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NVMI.csv  Saved
# Finished
# Get Data for :  NVNO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NVNO.csv  Saved
# Finished
# Get Data for :  NVO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NVO.csv  Saved
# Finished
# Get Data for :  NVOS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NVOS.csv  Saved
# Finished
# Get Data for :  NVR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NVR.csv  Saved
# Finished
# Get Data for :  NVRO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NVRO.csv  Saved
# Finished
# Get Data for :  NVS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NVS.csv  Saved
# Finished
# Get Data for :  NVSA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NVSA.csv  Saved
# Finished
# Get Data for :  NVST
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NVST.csv  Saved
# Finished
# Get Data for :  NVT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NVT.csv  Saved
# Finished
# Get Data for :  NVTA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NVTA.csv  Saved
# Finished
# Get Data for :  NVTS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NVTS.csv  Saved
# Finished
# Get Data for :  NVVE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NVVE.csv  Saved
# Finished
# Get Data for :  NWBI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NWBI.csv  Saved
# Finished
# Get Data for :  NWE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NWE.csv  Saved
# Finished
# Get Data for :  NWFL
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NWFL.csv  Saved
# Finished
# Get Data for :  NWG
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NWG.csv  Saved
# Finished
# Get Data for :  NWL
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NWL.csv  Saved
# Finished
# Get Data for :  NWLI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NWLI.csv  Saved
# Finished
# Get Data for :  NWN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NWN.csv  Saved
# Finished
# Get Data for :  NWPX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NWPX.csv  Saved
# Finished
# Get Data for :  NWS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NWS.csv  Saved
# Finished
# Get Data for :  NWSA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NWSA.csv  Saved
# Finished
# Get Data for :  NX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NX.csv  Saved
# Finished
# Get Data for :  NXE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NXE.csv  Saved
# Finished
# Get Data for :  NXGL
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NXGL.csv  Saved
# Finished
# Get Data for :  NXGN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NXGN.csv  Saved
# Finished
# Get Data for :  NXPI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NXPI.csv  Saved
# Finished
# Get Data for :  NXRT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NXRT.csv  Saved
# Finished
# Get Data for :  NXST
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NXST.csv  Saved
# Finished
# Get Data for :  NXTC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NXTC.csv  Saved
# Finished
# Get Data for :  NXTD
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NXTD.csv  Saved
# Finished
# Get Data for :  NXTP
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NXTP.csv  Saved
# Finished
# Get Data for :  NXU
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NXU.csv  Saved
# Finished
# Get Data for :  NYC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NYC.csv  Saved
# Finished
# Get Data for :  NYCB
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NYCB.csv  Saved
# Finished
# Get Data for :  NYMT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NYMT.csv  Saved
# Finished
# Get Data for :  NYMX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NYMX.csv  Saved
# Finished
# Get Data for :  NYT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NYT.csv  Saved
# Finished
# Get Data for :  NYXH
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/NYXH.csv  Saved
# Finished
# Get Data for :  O
# ...
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WRB.csv  Saved
# Finished
# Get Data for :  WRBY
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WRBY.csv  Saved
# Finished
# Get Data for :  WRE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WRE.csv  Saved
# Finished
# Get Data for :  WRK
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WRK.csv  Saved
# Finished
# Get Data for :  WRLD
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WRLD.csv  Saved
# Finished
# Get Data for :  WRN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WRN.csv  Saved
# Finished
# Get Data for :  WSBC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WSBC.csv  Saved
# Finished
# Get Data for :  WSBF
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WSBF.csv  Saved
# Finished
# Get Data for :  WSC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WSC.csv  Saved
# Finished
# Get Data for :  WSFS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WSFS.csv  Saved
# Finished
# Get Data for :  WSM
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WSM.csv  Saved
# Finished
# Get Data for :  WSO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WSO.csv  Saved
# Finished
# Get Data for :  WSR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WSR.csv  Saved
# Finished
# Get Data for :  WST
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WST.csv  Saved
# Finished
# Get Data for :  WSTG
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WSTG.csv  Saved
# Finished
# Get Data for :  WTBA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WTBA.csv  Saved
# Finished
# Get Data for :  WTER
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WTER.csv  Saved
# Finished
# Get Data for :  WTFC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WTFC.csv  Saved
# Finished
# Get Data for :  WTI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WTI.csv  Saved
# Finished
# Get Data for :  WTM
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WTM.csv  Saved
# Finished
# Get Data for :  WTRG
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WTRG.csv  Saved
# Finished
# Get Data for :  WTRH
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WTRH.csv  Saved
# Finished
# Get Data for :  WTS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WTS.csv  Saved
# Finished
# Get Data for :  WTT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WTT.csv  Saved
# Finished
# Get Data for :  WTTR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WTTR.csv  Saved
# Finished
# Get Data for :  WU
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WU.csv  Saved
# Finished
# Get Data for :  WULF
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WULF.csv  Saved
# Finished
# Get Data for :  WVE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WVE.csv  Saved
# Finished
# Get Data for :  WVFC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WVFC.csv  Saved
# Finished
# Get Data for :  WVVI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WVVI.csv  Saved
# Finished
# Get Data for :  WW
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WW.csv  Saved
# Finished
# Get Data for :  WWAC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WWAC.csv  Saved
# Finished
# Get Data for :  WWD
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WWD.csv  Saved
# Finished
# Get Data for :  WWE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WWE.csv  Saved
# Finished
# Get Data for :  WWR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WWR.csv  Saved
# Finished
# Get Data for :  WWW
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WWW.csv  Saved
# Finished
# Get Data for :  WY
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WY.csv  Saved
# Finished
# Get Data for :  WYNN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WYNN.csv  Saved
# Finished
# Get Data for :  WYY
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/WYY.csv  Saved
# Finished
# Get Data for :  X
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/X.csv  Saved
# Finished
# Get Data for :  XAIR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XAIR.csv  Saved
# Finished
# Get Data for :  XBIO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XBIO.csv  Saved
# Finished
# Get Data for :  XBIT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XBIT.csv  Saved
# Finished
# Get Data for :  XCUR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XCUR.csv  Saved
# Finished
# Get Data for :  XEL
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XEL.csv  Saved
# Finished
# Get Data for :  XELA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XELA.csv  Saved
# Finished
# Get Data for :  XELB
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XELB.csv  Saved
# Finished
# Get Data for :  XENE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XENE.csv  Saved
# Finished
# Get Data for :  XENT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XENT.csv  Saved
# Finished
# Get Data for :  XERS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XERS.csv  Saved
# Finished
# Get Data for :  XFIN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XFIN.csv  Saved
# Finished
# Get Data for :  XFOR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XFOR.csv  Saved
# Finished
# Get Data for :  XGN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XGN.csv  Saved
# Finished
# Get Data for :  XHR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XHR.csv  Saved
# Finished
# Get Data for :  XIN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XIN.csv  Saved
# Finished
# Get Data for :  XL
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XL.csv  Saved
# Finished
# Get Data for :  XLNX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XLNX.csv  Saved
# Finished
# Get Data for :  XLO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XLO.csv  Saved
# Finished
# Get Data for :  XM
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XM.csv  Saved
# Finished
# Get Data for :  XMTR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XMTR.csv  Saved
# Finished
# Get Data for :  XNCR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XNCR.csv  Saved
# Finished
# Get Data for :  XNET
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XNET.csv  Saved
# Finished
# Get Data for :  XOM
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XOM.csv  Saved
# Finished
# Get Data for :  XOMA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XOMA.csv  Saved
# Finished
# Get Data for :  XOS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XOS.csv  Saved
# Finished
# Get Data for :  XP
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XP.csv  Saved
# Finished
# Get Data for :  XPAX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XPAX.csv  Saved
# Finished
# Get Data for :  XPDI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XPDI.csv  Saved
# Finished
# Get Data for :  XPEL
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XPEL.csv  Saved
# Finished
# Get Data for :  XPER
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XPER.csv  Saved
# Finished
# Get Data for :  XPEV
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XPEV.csv  Saved
# Finished
# Get Data for :  XPL
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XPL.csv  Saved
# Finished
# Get Data for :  XPO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XPO.csv  Saved
# Finished
# Get Data for :  XPOA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XPOA.csv  Saved
# Finished
# Get Data for :  XPOF
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XPOF.csv  Saved
# Finished
# Get Data for :  XPRO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XPRO.csv  Saved
# Finished
# Get Data for :  XRAY
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XRAY.csv  Saved
# Finished
# Get Data for :  XRTX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XRTX.csv  Saved
# Finished
# Get Data for :  XRX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XRX.csv  Saved
# Finished
# Get Data for :  XSPA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XSPA.csv  Saved
# Finished
# Get Data for :  XTLB
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XTLB.csv  Saved
# Finished
# Get Data for :  XTNT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XTNT.csv  Saved
# Finished
# Get Data for :  XXII
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XXII.csv  Saved
# Finished
# Get Data for :  XYF
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XYF.csv  Saved
# Finished
# Get Data for :  XYL
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/XYL.csv  Saved
# Finished
# Get Data for :  Y
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/Y.csv  Saved
# Finished
# Get Data for :  YALA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/YALA.csv  Saved
# Finished
# Get Data for :  YCBD
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/YCBD.csv  Saved
# Finished
# Get Data for :  YELL
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/YELL.csv  Saved
# Finished
# Get Data for :  YELP
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/YELP.csv  Saved
# Finished
# Get Data for :  YETI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/YETI.csv  Saved
# Finished
# Get Data for :  YEXT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/YEXT.csv  Saved
# Finished
# Get Data for :  YGMZ
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/YGMZ.csv  Saved
# Finished
# Get Data for :  YI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/YI.csv  Saved
# Finished
# Get Data for :  YJ
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/YJ.csv  Saved
# Finished
# Get Data for :  YMAB
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/YMAB.csv  Saved
# Finished
# Get Data for :  YMM
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/YMM.csv  Saved
# Finished
# Get Data for :  YMTX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/YMTX.csv  Saved
# Finished
# Get Data for :  YNDX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/YNDX.csv  Saved
# Finished
# Get Data for :  YORW
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/YORW.csv  Saved
# Finished
# Get Data for :  YOU
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/YOU.csv  Saved
# Finished
# Get Data for :  YPF
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/YPF.csv  Saved
# Finished
# Get Data for :  YQ
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/YQ.csv  Saved
# Finished
# Get Data for :  YRD
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/YRD.csv  Saved
# Finished
# Get Data for :  YSAC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/YSAC.csv  Saved
# Finished
# Get Data for :  YSG
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/YSG.csv  Saved
# Finished
# Get Data for :  YTEN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/YTEN.csv  Saved
# Finished
# Get Data for :  YTPG
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/YTPG.csv  Saved
# Finished
# Get Data for :  YTRA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/YTRA.csv  Saved
# Finished
# Get Data for :  YUM
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/YUM.csv  Saved
# Finished
# Get Data for :  YUMC
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/YUMC.csv  Saved
# Finished
# Get Data for :  YVR
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/YVR.csv  Saved
# Finished
# Get Data for :  YY
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/YY.csv  Saved
# Finished
# Get Data for :  Z
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/Z.csv  Saved
# Finished
# Get Data for :  ZBH
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZBH.csv  Saved
# Finished
# Get Data for :  ZBRA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZBRA.csv  Saved
# Finished
# Get Data for :  ZCMD
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZCMD.csv  Saved
# Finished
# Get Data for :  ZD
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZD.csv  Saved
# Finished
# Get Data for :  ZDGE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZDGE.csv  Saved
# Finished
# Get Data for :  ZEAL
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZEAL.csv  Saved
# Finished
# Get Data for :  ZEN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZEN.csv  Saved
# Finished
# Get Data for :  ZENV
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZENV.csv  Saved
# Finished
# Get Data for :  ZEPP
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZEPP.csv  Saved
# Finished
# Get Data for :  ZEST
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZEST.csv  Saved
# Finished
# Get Data for :  ZETA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZETA.csv  Saved
# Finished
# Get Data for :  ZEUS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZEUS.csv  Saved
# Finished
# Get Data for :  ZEV
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZEV.csv  Saved
# Finished
# Get Data for :  ZG
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZG.csv  Saved
# Finished
# Get Data for :  ZGN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZGN.csv  Saved
# Finished
# Get Data for :  ZGNX
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZGNX.csv  Saved
# Finished
# Get Data for :  ZH
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZH.csv  Saved
# Finished
# Get Data for :  ZI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZI.csv  Saved
# Finished
# Get Data for :  ZIM
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZIM.csv  Saved
# Finished
# Get Data for :  ZION
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZION.csv  Saved
# Finished
# Get Data for :  ZIOP
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZIOP.csv  Saved
# Finished
# Get Data for :  ZIP
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZIP.csv  Saved
# Finished
# Get Data for :  ZIVO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZIVO.csv  Saved
# Finished
# Get Data for :  ZKIN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZKIN.csv  Saved
# Finished
# Get Data for :  ZLAB
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZLAB.csv  Saved
# Finished
# Get Data for :  ZM
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZM.csv  Saved
# Finished
# Get Data for :  ZME
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZME.csv  Saved
# Finished
# Get Data for :  ZNGA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZNGA.csv  Saved
# Finished
# Get Data for :  ZNH
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZNH.csv  Saved
# Finished
# Get Data for :  ZNTE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZNTE.csv  Saved
# Finished
# Get Data for :  ZNTL
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZNTL.csv  Saved
# Finished
# Get Data for :  ZOM
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZOM.csv  Saved
# Finished
# Get Data for :  ZS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZS.csv  Saved
# Finished
# Get Data for :  ZSAN
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZSAN.csv  Saved
# Finished
# Get Data for :  ZT
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZT.csv  Saved
# Finished
# Get Data for :  ZTO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZTO.csv  Saved
# Finished
# Get Data for :  ZTS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZTS.csv  Saved
# Finished
# Get Data for :  ZUMZ
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZUMZ.csv  Saved
# Finished
# Get Data for :  ZUO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZUO.csv  Saved
# Finished
# Get Data for :  ZVIA
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZVIA.csv  Saved
# Finished
# Get Data for :  ZVO
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZVO.csv  Saved
# Finished
# Get Data for :  ZWRK
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZWRK.csv  Saved
# Finished
# Get Data for :  ZWS
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZWS.csv  Saved
# Finished
# Get Data for :  ZY
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZY.csv  Saved
# Finished
# Get Data for :  ZYME
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZYME.csv  Saved
# Finished
# Get Data for :  ZYNE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZYNE.csv  Saved
# Finished
# Get Data for :  ZYXI
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/ZYXI.csv  Saved
# Finished
# Get Data for :  TRUE
# C:/Users/hansf/git/python/aktie/Python4Finance/stocks/TRUE.csv  Saved
# Finished
