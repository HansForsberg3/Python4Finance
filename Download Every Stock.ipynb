# %%
# Provides ways to work with large multidimensional arrays
import numpy as np 
# Allows for further data manipulation and analysis
import pandas as pd 
import matplotlib.pyplot as plt # Plotting
import matplotlib.dates as mdates # Styling dates
# %matplotlib inline

import datetime as dt # For defining dates

import time

# In Powershell Prompt : conda install -c conda-forge multitasking
# pip install -i https://pypi.anaconda.org/ranaroussi/simple yfinance

import yfinance as yf

# %% [markdown]
# ## YFinance

# %%
def get_info_on_stock(ticker):
    stock = yf.Ticker(ticker)

    # Get overview of company
    print(stock.info)

    # Get historical closing price data
    hist = stock.history(period="max")["Close"]
    print(hist.head())

    # Get financial data
    print(stock.financials)

    # Get major share holders
    print(stock.major_holders)

    # Get institutional holders
    print(stock.institutional_holders)

    # Get balance sheet
    print(stock.balance_sheet)

    # Show cashflow
    print(stock.cashflow)

    # Show earnings
    print(stock.earnings)

    # Show analysts recommendations
    print(stock.recommendations)

# %%
# get_info_on_stock("14D.AX")

# %% [markdown]
# ## Holds Stocks Not Downloaded

# %%
stocks_not_downloaded = []
missing_stocks = []

# %% [markdown]
# ## Function that Returns a Stock Dataframe from a CSV

# %%
# Reads a dataframe from the CSV file, changes index to date and returns it
def get_stock_df_from_csv(folder, ticker):
    
    # Try to get the file and if it doesn't exist issue a warning
    try:
        df = pd.read_csv(folder + ticker + '.csv')
    except FileNotFoundError:
        print("File Doesn't Exist")
    else:
        return df

# %% [markdown]
# ## Returns a Named Columns Data from a CSV

# %%
def get_column_from_csv(file, col_name):
    # Try to get the file and if it doesn't exist issue a warning
    try:
        df = pd.read_csv(file)
    except FileNotFoundError:
        print("File Doesn't Exist")
    else:
        return df[col_name]

# %% [markdown]
# ## Get Stock Tickers

# %%
# Total of 3898 tickers
# Windows version
# tickers = get_column_from_csv("D:/Python for Finance/Australia.csv", "Ticker")
# MacOS Version
path = "/Users/derekbanas/Documents/Tutorials/Python for Finance/Australia.csv"
tickers = get_column_from_csv(path, "Ticker")
tickers

for x in tickers:
    print(x, end=", ")

# %% [markdown]
# ## Function that Saves Stock Data to CSV

# %%
# Function that gets a dataframe by providing a ticker and starting date
def save_to_csv_from_yahoo(folder, ticker):
    
    stock = yf.Ticker(ticker)
    
    try:
        print("Get Data for : ", ticker)
        # Get historical closing price data
        df = stock.history(period="max")["Close"]
    
        # Wait 2 seconds
        time.sleep(2)
        
        if df.empty:
            stocks_not_downloaded.append(ticker)
        
        # Remove the period for saving the file name
        # Save data to a CSV file
        # File to save to 
        the_file = folder + ticker.replace(".", "_") + '.csv'
        print(the_file, " Saved")
        df.to_csv(the_file)
    except Exception as ex:
        stocks_not_downloaded.append(ticker)
        print("Couldn't Get Data for :", ticker)

# %% [markdown]
# ## Get 5 Years of Data for the 1st 20 Stocks

# %%
# Folder used to store stock data
folder = "/Users/derekbanas/Documents/Tutorials/Python for Finance/Australian_Stocks/"

# for x in range(20):
#   save_to_csv_from_yahoo(folder, tickers[x])
# print("Finished")

# %% [markdown]
# ## Get Next 80 Stocks

# %%
# for x in range(20, 100):
#   save_to_csv_from_yahoo(folder, tickers[x])
# print("Finished")

# %%
# for x in range(2000, 3898):
#   save_to_csv_from_yahoo(folder, tickers[x])
# print("Finished")
# stocks_not_downloaded

# %% [markdown]
# ## Get Euronext Tickers

# %%
# # Total of 1648 tickers
# tickers = get_column_from_csv("D:/Python for Finance/Euronext.csv", "Ticker")
# tickers

# for x in tickers:
#     print(x, end=", ")

# %%
# folder = "D:/Python for Finance/Euronext_Stocks/"
# for x in range(0, 1648):
#   save_to_csv_from_yahoo(folder, tickers[x])
# print("Finished")
# stocks_not_downloaded

# %% [markdown]
# ## Get Frankfurt Tickers

# %%
# # Total of 496 tickers
# tickers = get_column_from_csv("D:/Python for Finance/Frankfurt.csv", "Ticker")
# tickers

# for x in tickers:
#     print(x, end=", ")

# %%
# folder = "D:/Python for Finance/Frankfurt_Stocks/"
# for x in range(0, 495):
#   save_to_csv_from_yahoo(folder, tickers[x])
# print("Finished")
# stocks_not_downloaded

# %% [markdown]
# ## Get FTSE Stocks

# %%
# # Total of 620 tickers
# tickers = get_column_from_csv("D:/Python for Finance/FTSE.csv", "Ticker")
# tickers

# for x in tickers:
#     print(x, end=", ")

# %%
# folder = "D:/Python for Finance/FTSE_Stocks/"
# for x in range(0, 619):
#   save_to_csv_from_yahoo(folder, tickers[x])
# print("Finished")
# stocks_not_downloaded

# %% [markdown]
# ## Get Johannesburg Stocks

# %%
# # Total of 400 tickers
# tickers = get_column_from_csv("D:/Python for Finance/Johannesburg.csv", "Ticker")
# tickers

# for x in tickers:
#     print(x, end=", ")

# %%
# folder = "D:/Python for Finance/Johannesburg_Stocks/"
# for x in range(0, 399):
#   save_to_csv_from_yahoo(folder, tickers[x])
# print("Finished")
# stocks_not_downloaded

# %% [markdown]
# ## Get NASDAQ

# %%
# # Total of 2968 tickers
# tickers = get_column_from_csv("D:/Python for Finance/Nasdaq.csv", "Ticker")
# tickers

# for x in tickers:
#     print(x, end=", ")

# %%
# folder = "D:/Python for Finance/Nasdaq_Stocks/"
# for x in range(0, 2967):
#   save_to_csv_from_yahoo(folder, tickers[x])
# print("Finished")
# stocks_not_downloaded

# %% [markdown]
# ## Get NYSE

# %%
# # Total of 2626 tickers
# tickers = get_column_from_csv("D:/Python for Finance/NYSE.csv", "Ticker")
# tickers

# for x in tickers:
#     print(x, end=", ")

# %%
# folder = "D:/Python for Finance/NYSE_Stocks/"
# for x in range(0, 2625):
#   save_to_csv_from_yahoo(folder, tickers[x])
# print("Finished")
# stocks_not_downloaded

# %% [markdown]
# ## Get Russell 2000

# %%
# Total of 2033 tickers
tickers = get_column_from_csv("D:/Python for Finance/Russell2000.csv", "Ticker")
tickers

for x in tickers:
    print(x, end=", ")

# %%
folder = "D:/Python for Finance/Russell2000_Stocks/"
for x in range(1761, 2032):
  save_to_csv_from_yahoo(folder, tickers[x])
print("Finished")
stocks_not_downloaded
# Out:
# Get Data for :  DS
# D:/Python for Finance/Russell2000_Stocks/DS.csv  Saved
# Get Data for :  GLUE
# D:/Python for Finance/Russell2000_Stocks/GLUE.csv  Saved
# Get Data for :  INTA
# D:/Python for Finance/Russell2000_Stocks/INTA.csv  Saved
# Get Data for :  DAWN
# D:/Python for Finance/Russell2000_Stocks/DAWN.csv  Saved
# Get Data for :  SOLY
# D:/Python for Finance/Russell2000_Stocks/SOLY.csv  Saved
# Get Data for :  LCUT
# D:/Python for Finance/Russell2000_Stocks/LCUT.csv  Saved
# Get Data for :  USLM
# D:/Python for Finance/Russell2000_Stocks/USLM.csv  Saved
# Get Data for :  CDAK
# D:/Python for Finance/Russell2000_Stocks/CDAK.csv  Saved
# Get Data for :  ICAD
# D:/Python for Finance/Russell2000_Stocks/ICAD.csv  Saved
# Get Data for :  AWH
# D:/Python for Finance/Russell2000_Stocks/AWH.csv  Saved
# Get Data for :  FLMN
# D:/Python for Finance/Russell2000_Stocks/FLMN.csv  Saved
# Get Data for :  ATNX
# D:/Python for Finance/Russell2000_Stocks/ATNX.csv  Saved
# Get Data for :  NEXI
# D:/Python for Finance/Russell2000_Stocks/NEXI.csv  Saved
# Get Data for :  POWL
# D:/Python for Finance/Russell2000_Stocks/POWL.csv  Saved
# Get Data for :  QTNT
# D:/Python for Finance/Russell2000_Stocks/QTNT.csv  Saved
# Get Data for :  INFU
# D:/Python for Finance/Russell2000_Stocks/INFU.csv  Saved
# Get Data for :  EYPT
# D:/Python for Finance/Russell2000_Stocks/EYPT.csv  Saved
# Get Data for :  CTXR
# D:/Python for Finance/Russell2000_Stocks/CTXR.csv  Saved
# Get Data for :  HNST
# D:/Python for Finance/Russell2000_Stocks/HNST.csv  Saved
# Get Data for :  USX
# D:/Python for Finance/Russell2000_Stocks/USX.csv  Saved
# Get Data for :  MHLD
# D:/Python for Finance/Russell2000_Stocks/MHLD.csv  Saved
# Get Data for :  PSTL
# D:/Python for Finance/Russell2000_Stocks/PSTL.csv  Saved
# Get Data for :  EIGR
# D:/Python for Finance/Russell2000_Stocks/EIGR.csv  Saved
# Get Data for :  RLGT
# D:/Python for Finance/Russell2000_Stocks/RLGT.csv  Saved
# Get Data for :  TARS
# D:/Python for Finance/Russell2000_Stocks/TARS.csv  Saved
# Get Data for :  GRPH
# D:/Python for Finance/Russell2000_Stocks/GRPH.csv  Saved
# Get Data for :  BVS
# D:/Python for Finance/Russell2000_Stocks/BVS.csv  Saved
# Get Data for :  IRMD
# D:/Python for Finance/Russell2000_Stocks/IRMD.csv  Saved
# Get Data for :  FDBC
# D:/Python for Finance/Russell2000_Stocks/FDBC.csv  Saved
# Get Data for :  ITI
# D:/Python for Finance/Russell2000_Stocks/ITI.csv  Saved
# Get Data for :  AGS
# D:/Python for Finance/Russell2000_Stocks/AGS.csv  Saved
# Get Data for :  THRY
# D:/Python for Finance/Russell2000_Stocks/THRY.csv  Saved
# Get Data for :  SEEL
# D:/Python for Finance/Russell2000_Stocks/SEEL.csv  Saved
# Get Data for :  ZYXI
# D:/Python for Finance/Russell2000_Stocks/ZYXI.csv  Saved
# Get Data for :  FREQ
# D:/Python for Finance/Russell2000_Stocks/FREQ.csv  Saved
# Get Data for :  NGMS
# D:/Python for Finance/Russell2000_Stocks/NGMS.csv  Saved
# Get Data for :  FBIO
# D:/Python for Finance/Russell2000_Stocks/FBIO.csv  Saved
# Get Data for :  BRT
# D:/Python for Finance/Russell2000_Stocks/BRT.csv  Saved
# Get Data for :  DGICA
# D:/Python for Finance/Russell2000_Stocks/DGICA.csv  Saved
# Get Data for :  CECE
# D:/Python for Finance/Russell2000_Stocks/CECE.csv  Saved
# Get Data for :  IMGO
# D:/Python for Finance/Russell2000_Stocks/IMGO.csv  Saved
# Get Data for :  IHC
# D:/Python for Finance/Russell2000_Stocks/IHC.csv  Saved
# Get Data for :  HFFG
# D:/Python for Finance/Russell2000_Stocks/HFFG.csv  Saved
# Get Data for :  EWTX
# D:/Python for Finance/Russell2000_Stocks/EWTX.csv  Saved
# Get Data for :  MCBC
# D:/Python for Finance/Russell2000_Stocks/MCBC.csv  Saved
# Get Data for :  NNBR
# D:/Python for Finance/Russell2000_Stocks/NNBR.csv  Saved
# Get Data for :  CBNK
# D:/Python for Finance/Russell2000_Stocks/CBNK.csv  Saved
# Get Data for :  LBC
# D:/Python for Finance/Russell2000_Stocks/LBC.csv  Saved
# Get Data for :  ATER
# D:/Python for Finance/Russell2000_Stocks/ATER.csv  Saved
# Get Data for :  EGAN
# D:/Python for Finance/Russell2000_Stocks/EGAN.csv  Saved
# Get Data for :  PBYI
# D:/Python for Finance/Russell2000_Stocks/PBYI.csv  Saved
# Get Data for :  ZY
# D:/Python for Finance/Russell2000_Stocks/ZY.csv  Saved
# Get Data for :  AVNW
# D:/Python for Finance/Russell2000_Stocks/AVNW.csv  Saved
# Get Data for :  IPSC
# D:/Python for Finance/Russell2000_Stocks/IPSC.csv  Saved
# Get Data for :  FLXS
# D:/Python for Finance/Russell2000_Stocks/FLXS.csv  Saved
# Get Data for :  NCMI
# D:/Python for Finance/Russell2000_Stocks/NCMI.csv  Saved
# Get Data for :  AQB
# D:/Python for Finance/Russell2000_Stocks/AQB.csv  Saved
# Get Data for :  AVRO
# D:/Python for Finance/Russell2000_Stocks/AVRO.csv  Saved
# Get Data for :  MGTA
# D:/Python for Finance/Russell2000_Stocks/MGTA.csv  Saved
# Get Data for :  AXDX
# D:/Python for Finance/Russell2000_Stocks/AXDX.csv  Saved
# Get Data for :  PLPC
# D:/Python for Finance/Russell2000_Stocks/PLPC.csv  Saved
# Get Data for :  IBIO
# D:/Python for Finance/Russell2000_Stocks/IBIO.csv  Saved
# Get Data for :  BBCP
# D:/Python for Finance/Russell2000_Stocks/BBCP.csv  Saved
# Get Data for :  DAKT
# D:/Python for Finance/Russell2000_Stocks/DAKT.csv  Saved
# Get Data for :  AFCG
# D:/Python for Finance/Russell2000_Stocks/AFCG.csv  Saved
# Get Data for :  CSLT
# D:/Python for Finance/Russell2000_Stocks/CSLT.csv  Saved
# Get Data for :  VMD
# D:/Python for Finance/Russell2000_Stocks/VMD.csv  Saved
# Get Data for :  OCX
# D:/Python for Finance/Russell2000_Stocks/OCX.csv  Saved
# Get Data for :  NUVL
# D:/Python for Finance/Russell2000_Stocks/NUVL.csv  Saved
# Get Data for :  DZSI
# D:/Python for Finance/Russell2000_Stocks/DZSI.csv  Saved
# Get Data for :  OUST
# D:/Python for Finance/Russell2000_Stocks/OUST.csv  Saved
# Get Data for :  SCWX
# D:/Python for Finance/Russell2000_Stocks/SCWX.csv  Saved
# Get Data for :  XBIT
# D:/Python for Finance/Russell2000_Stocks/XBIT.csv  Saved
# Get Data for :  PKOH
# D:/Python for Finance/Russell2000_Stocks/PKOH.csv  Saved
# Get Data for :  OTLK
# D:/Python for Finance/Russell2000_Stocks/OTLK.csv  Saved
# Get Data for :  UAVS
# D:/Python for Finance/Russell2000_Stocks/UAVS.csv  Saved
# Get Data for :  FORA
# D:/Python for Finance/Russell2000_Stocks/FORA.csv  Saved
# Get Data for :  ESCA
# D:/Python for Finance/Russell2000_Stocks/ESCA.csv  Saved
# Get Data for :  FF
# D:/Python for Finance/Russell2000_Stocks/FF.csv  Saved
# Get Data for :  DSGN
# D:/Python for Finance/Russell2000_Stocks/DSGN.csv  Saved
# Get Data for :  PSTX
# D:/Python for Finance/Russell2000_Stocks/PSTX.csv  Saved
# Get Data for :  MG
# D:/Python for Finance/Russell2000_Stocks/MG.csv  Saved
# Get Data for :  ANGN
# D:/Python for Finance/Russell2000_Stocks/ANGN.csv  Saved
# Get Data for :  TRVN
# D:/Python for Finance/Russell2000_Stocks/TRVN.csv  Saved
# Get Data for :  TNXP
# D:/Python for Finance/Russell2000_Stocks/TNXP.csv  Saved
# Get Data for :  NBEV
# D:/Python for Finance/Russell2000_Stocks/NBEV.csv  Saved
# Get Data for :  MRLN
# D:/Python for Finance/Russell2000_Stocks/MRLN.csv  Saved
# Get Data for :  SNPO
# D:/Python for Finance/Russell2000_Stocks/SNPO.csv  Saved
# Get Data for :  HMTV
# D:/Python for Finance/Russell2000_Stocks/HMTV.csv  Saved
# Get Data for :  XL
# D:/Python for Finance/Russell2000_Stocks/XL.csv  Saved
# Get Data for :  GLRE
# D:/Python for Finance/Russell2000_Stocks/GLRE.csv  Saved
# Get Data for :  HRTG
# D:/Python for Finance/Russell2000_Stocks/HRTG.csv  Saved
# Get Data for :  CASA
# D:/Python for Finance/Russell2000_Stocks/CASA.csv  Saved
# Get Data for :  SBTX
# D:/Python for Finance/Russell2000_Stocks/SBTX.csv  Saved
# Get Data for :  FRGI
# D:/Python for Finance/Russell2000_Stocks/FRGI.csv  Saved
# Get Data for :  ODC
# D:/Python for Finance/Russell2000_Stocks/ODC.csv  Saved
# Get Data for :  CRMD
# D:/Python for Finance/Russell2000_Stocks/CRMD.csv  Saved
# Get Data for :  ONCR
# D:/Python for Finance/Russell2000_Stocks/ONCR.csv  Saved
# Get Data for :  ETNB
# D:/Python for Finance/Russell2000_Stocks/ETNB.csv  Saved
# Get Data for :  SKYT
# D:/Python for Finance/Russell2000_Stocks/SKYT.csv  Saved
# Get Data for :  VLGEA
# D:/Python for Finance/Russell2000_Stocks/VLGEA.csv  Saved
# Get Data for :  BDTX
# D:/Python for Finance/Russell2000_Stocks/BDTX.csv  Saved
# Get Data for :  DRIO
# D:/Python for Finance/Russell2000_Stocks/DRIO.csv  Saved
# Get Data for :  TKNO
# D:/Python for Finance/Russell2000_Stocks/TKNO.csv  Saved
# Get Data for :  VINC
# D:/Python for Finance/Russell2000_Stocks/VINC.csv  Saved
# Get Data for :  ONCT
# D:/Python for Finance/Russell2000_Stocks/ONCT.csv  Saved
# Get Data for :  IMRX
# D:/Python for Finance/Russell2000_Stocks/IMRX.csv  Saved
# Get Data for :  VOXX
# D:/Python for Finance/Russell2000_Stocks/VOXX.csv  Saved
# Get Data for :  WVE
# D:/Python for Finance/Russell2000_Stocks/WVE.csv  Saved
# Get Data for :  ADVM
# D:/Python for Finance/Russell2000_Stocks/ADVM.csv  Saved
# Get Data for :  NATR
# D:/Python for Finance/Russell2000_Stocks/NATR.csv  Saved
# Get Data for :  TIG
# D:/Python for Finance/Russell2000_Stocks/TIG.csv  Saved
# Get Data for :  KLTR
# D:/Python for Finance/Russell2000_Stocks/KLTR.csv  Saved
# Get Data for :  RVP
# D:/Python for Finance/Russell2000_Stocks/RVP.csv  Saved
# Get Data for :  AVTE
# D:/Python for Finance/Russell2000_Stocks/AVTE.csv  Saved
# Get Data for :  VATE
# D:/Python for Finance/Russell2000_Stocks/VATE.csv  Saved
# Get Data for :  CURV
# D:/Python for Finance/Russell2000_Stocks/CURV.csv  Saved
# Get Data for :  MXCT
# D:/Python for Finance/Russell2000_Stocks/MXCT.csv  Saved
# Get Data for :  ALKT
# D:/Python for Finance/Russell2000_Stocks/ALKT.csv  Saved
# Get Data for :  BSET
# D:/Python for Finance/Russell2000_Stocks/BSET.csv  Saved
# Get Data for :  NODK
# D:/Python for Finance/Russell2000_Stocks/NODK.csv  Saved
# Get Data for :  PRLD
# D:/Python for Finance/Russell2000_Stocks/PRLD.csv  Saved
# Get Data for :  AFIB
# D:/Python for Finance/Russell2000_Stocks/AFIB.csv  Saved
# Get Data for :  CELC
# D:/Python for Finance/Russell2000_Stocks/CELC.csv  Saved
# Get Data for :  NATH
# D:/Python for Finance/Russell2000_Stocks/NATH.csv  Saved
# Get Data for :  DLTH
# D:/Python for Finance/Russell2000_Stocks/DLTH.csv  Saved
# Get Data for :  EVI
# D:/Python for Finance/Russell2000_Stocks/EVI.csv  Saved
# Get Data for :  MEC
# D:/Python for Finance/Russell2000_Stocks/MEC.csv  Saved
# Get Data for :  KRUS
# D:/Python for Finance/Russell2000_Stocks/KRUS.csv  Saved
# Get Data for :  PZN
# D:/Python for Finance/Russell2000_Stocks/PZN.csv  Saved
# Get Data for :  STIM
# D:/Python for Finance/Russell2000_Stocks/STIM.csv  Saved
# Get Data for :  SNSE
# D:/Python for Finance/Russell2000_Stocks/SNSE.csv  Saved
# Get Data for :  MBIO
# D:/Python for Finance/Russell2000_Stocks/MBIO.csv  Saved
# Get Data for :  PTSI
# D:/Python for Finance/Russell2000_Stocks/PTSI.csv  Saved
# Get Data for :  ASLE
# D:/Python for Finance/Russell2000_Stocks/ASLE.csv  Saved
# Get Data for :  CDZI
# D:/Python for Finance/Russell2000_Stocks/CDZI.csv  Saved
# Get Data for :  FOA
# D:/Python for Finance/Russell2000_Stocks/FOA.csv  Saved
# Get Data for :  GLSI
# D:/Python for Finance/Russell2000_Stocks/GLSI.csv  Saved
# Get Data for :  XOMA
# D:/Python for Finance/Russell2000_Stocks/XOMA.csv  Saved
# Get Data for :  SESN
# D:/Python for Finance/Russell2000_Stocks/SESN.csv  Saved
# Get Data for :  HBT
# D:/Python for Finance/Russell2000_Stocks/HBT.csv  Saved
# Get Data for :  ACET
# D:/Python for Finance/Russell2000_Stocks/ACET.csv  Saved
# Get Data for :  LAZY
# D:/Python for Finance/Russell2000_Stocks/LAZY.csv  Saved
# Get Data for :  VRCA
# D:/Python for Finance/Russell2000_Stocks/VRCA.csv  Saved
# Get Data for :  ADN
# D:/Python for Finance/Russell2000_Stocks/ADN.csv  Saved
# Get Data for :  IVC
# D:/Python for Finance/Russell2000_Stocks/IVC.csv  Saved
# Get Data for :  OMIC
# D:/Python for Finance/Russell2000_Stocks/OMIC.csv  Saved
# Get Data for :  LVO
# D:/Python for Finance/Russell2000_Stocks/LVO.csv  Saved
# Get Data for :  ULH
# D:/Python for Finance/Russell2000_Stocks/ULH.csv  Saved
# Get Data for :  CYT
# D:/Python for Finance/Russell2000_Stocks/CYT.csv  Saved
# Get Data for :  CRDA
# - CRDA: No data found for this date range, symbol may be delisted
# D:/Python for Finance/Russell2000_Stocks/CRDA.csv  Saved
# Get Data for :  CSSE
# D:/Python for Finance/Russell2000_Stocks/CSSE.csv  Saved
# Get Data for :  PBFS
# D:/Python for Finance/Russell2000_Stocks/PBFS.csv  Saved
# Get Data for :  TERN
# D:/Python for Finance/Russell2000_Stocks/TERN.csv  Saved
# Get Data for :  GBL
# D:/Python for Finance/Russell2000_Stocks/GBL.csv  Saved
# Get Data for :  DSP
# D:/Python for Finance/Russell2000_Stocks/DSP.csv  Saved
# Get Data for :  INZY
# D:/Python for Finance/Russell2000_Stocks/INZY.csv  Saved
# Get Data for :  BCEL
# D:/Python for Finance/Russell2000_Stocks/BCEL.csv  Saved
# Get Data for :  AOMR
# D:/Python for Finance/Russell2000_Stocks/AOMR.csv  Saved
# Get Data for :  HOFV
# D:/Python for Finance/Russell2000_Stocks/HOFV.csv  Saved
# Get Data for :  FSBC
# D:/Python for Finance/Russell2000_Stocks/FSBC.csv  Saved
# Get Data for :  KVHI
# D:/Python for Finance/Russell2000_Stocks/KVHI.csv  Saved
# Get Data for :  LEGH
# D:/Python for Finance/Russell2000_Stocks/LEGH.csv  Saved
# Get Data for :  OYST
# D:/Python for Finance/Russell2000_Stocks/OYST.csv  Saved
# Get Data for :  HYRE
# D:/Python for Finance/Russell2000_Stocks/HYRE.csv  Saved
# Get Data for :  ABSI
# D:/Python for Finance/Russell2000_Stocks/ABSI.csv  Saved
# Get Data for :  VIA
# D:/Python for Finance/Russell2000_Stocks/VIA.csv  Saved
# Get Data for :  SLDB
# D:/Python for Finance/Russell2000_Stocks/SLDB.csv  Saved
# Get Data for :  BH
# D:/Python for Finance/Russell2000_Stocks/BH.csv  Saved
# Get Data for :  XGN
# D:/Python for Finance/Russell2000_Stocks/XGN.csv  Saved
# Get Data for :  RPID
# D:/Python for Finance/Russell2000_Stocks/RPID.csv  Saved
# Get Data for :  ALPN
# D:/Python for Finance/Russell2000_Stocks/ALPN.csv  Saved
# Get Data for :  GBOX
# D:/Python for Finance/Russell2000_Stocks/GBOX.csv  Saved
# Get Data for :  TALS
# D:/Python for Finance/Russell2000_Stocks/TALS.csv  Saved
# Get Data for :  PPTA
# D:/Python for Finance/Russell2000_Stocks/PPTA.csv  Saved
# Get Data for :  ATCX
# D:/Python for Finance/Russell2000_Stocks/ATCX.csv  Saved
# Get Data for :  CVRX
# D:/Python for Finance/Russell2000_Stocks/CVRX.csv  Saved
# Get Data for :  OMGA
# D:/Python for Finance/Russell2000_Stocks/OMGA.csv  Saved
# Get Data for :  HARP
# D:/Python for Finance/Russell2000_Stocks/HARP.csv  Saved
# Get Data for :  ABOS
# D:/Python for Finance/Russell2000_Stocks/ABOS.csv  Saved
# Get Data for :  IMUX
# D:/Python for Finance/Russell2000_Stocks/IMUX.csv  Saved
# Get Data for :  FTCI
# D:/Python for Finance/Russell2000_Stocks/FTCI.csv  Saved
# Get Data for :  JOAN
# D:/Python for Finance/Russell2000_Stocks/JOAN.csv  Saved
# Get Data for :  TAST
# D:/Python for Finance/Russell2000_Stocks/TAST.csv  Saved
# Get Data for :  EAR
# D:/Python for Finance/Russell2000_Stocks/EAR.csv  Saved
# Get Data for :  XPOF
# D:/Python for Finance/Russell2000_Stocks/XPOF.csv  Saved
# Get Data for :  OB
# D:/Python for Finance/Russell2000_Stocks/OB.csv  Saved
# Get Data for :  VERA
# D:/Python for Finance/Russell2000_Stocks/VERA.csv  Saved
# Get Data for :  FRBK
# D:/Python for Finance/Russell2000_Stocks/FRBK.csv  Saved
# Get Data for :  ZVIA
# D:/Python for Finance/Russell2000_Stocks/ZVIA.csv  Saved
# Get Data for :  MILE
# D:/Python for Finance/Russell2000_Stocks/MILE.csv  Saved
# Get Data for :  CSPR
# D:/Python for Finance/Russell2000_Stocks/CSPR.csv  Saved
# Get Data for :  HOWL
# D:/Python for Finance/Russell2000_Stocks/HOWL.csv  Saved
# Get Data for :  EEX
# D:/Python for Finance/Russell2000_Stocks/EEX.csv  Saved
# Get Data for :  AVTX
# D:/Python for Finance/Russell2000_Stocks/AVTX.csv  Saved
# Get Data for :  FTHM
# D:/Python for Finance/Russell2000_Stocks/FTHM.csv  Saved
# Get Data for :  RLYB
# D:/Python for Finance/Russell2000_Stocks/RLYB.csv  Saved
# Get Data for :  CLNN
# D:/Python for Finance/Russell2000_Stocks/CLNN.csv  Saved
# Get Data for :  TLMD
# D:/Python for Finance/Russell2000_Stocks/TLMD.csv  Saved
# Get Data for :  SMMT
# D:/Python for Finance/Russell2000_Stocks/SMMT.csv  Saved
# Get Data for :  INNV
# D:/Python for Finance/Russell2000_Stocks/INNV.csv  Saved
# Get Data for :  WLFC
# D:/Python for Finance/Russell2000_Stocks/WLFC.csv  Saved
# Get Data for :  NGVC
# D:/Python for Finance/Russell2000_Stocks/NGVC.csv  Saved
# Get Data for :  NPCE
# D:/Python for Finance/Russell2000_Stocks/NPCE.csv  Saved
# Get Data for :  ARDX
# D:/Python for Finance/Russell2000_Stocks/ARDX.csv  Saved
# Get Data for :  GTBP
# D:/Python for Finance/Russell2000_Stocks/GTBP.csv  Saved
# Get Data for :  KALA
# D:/Python for Finance/Russell2000_Stocks/KALA.csv  Saved
# Get Data for :  LSF
# D:/Python for Finance/Russell2000_Stocks/LSF.csv  Saved
# Get Data for :  HBB
# D:/Python for Finance/Russell2000_Stocks/HBB.csv  Saved
# Get Data for :  SMED
# D:/Python for Finance/Russell2000_Stocks/SMED.csv  Saved
# Get Data for :  VEL
# D:/Python for Finance/Russell2000_Stocks/VEL.csv  Saved
# Get Data for :  RXST
# D:/Python for Finance/Russell2000_Stocks/RXST.csv  Saved
# Get Data for :  CNVY
# D:/Python for Finance/Russell2000_Stocks/CNVY.csv  Saved
# Get Data for :  ELYM
# D:/Python for Finance/Russell2000_Stocks/ELYM.csv  Saved
# Get Data for :  MPX
# D:/Python for Finance/Russell2000_Stocks/MPX.csv  Saved
# Get Data for :  BMEA
# D:/Python for Finance/Russell2000_Stocks/BMEA.csv  Saved
# Get Data for :  IKNA
# D:/Python for Finance/Russell2000_Stocks/IKNA.csv  Saved
# Get Data for :  CLPR
# D:/Python for Finance/Russell2000_Stocks/CLPR.csv  Saved
# Get Data for :  KLDO
# D:/Python for Finance/Russell2000_Stocks/KLDO.csv  Saved
# Get Data for :  HOOK
# D:/Python for Finance/Russell2000_Stocks/HOOK.csv  Saved
# Get Data for :  FLNT
# D:/Python for Finance/Russell2000_Stocks/FLNT.csv  Saved
# Get Data for :  HQI
# D:/Python for Finance/Russell2000_Stocks/HQI.csv  Saved
# Get Data for :  RAIN
# D:/Python for Finance/Russell2000_Stocks/RAIN.csv  Saved
# Get Data for :  PLM
# D:/Python for Finance/Russell2000_Stocks/PLM.csv  Saved
# Get Data for :  IBEX
# D:/Python for Finance/Russell2000_Stocks/IBEX.csv  Saved
# Get Data for :  MBII
# D:/Python for Finance/Russell2000_Stocks/MBII.csv  Saved
# Get Data for :  DIBS
# D:/Python for Finance/Russell2000_Stocks/DIBS.csv  Saved
# Get Data for :  TH
# D:/Python for Finance/Russell2000_Stocks/TH.csv  Saved
# Get Data for :  LSEA
# D:/Python for Finance/Russell2000_Stocks/LSEA.csv  Saved
# Get Data for :  AKYA
# D:/Python for Finance/Russell2000_Stocks/AKYA.csv  Saved
# Get Data for :  SRT
# D:/Python for Finance/Russell2000_Stocks/SRT.csv  Saved
# Get Data for :  KRT
# D:/Python for Finance/Russell2000_Stocks/KRT.csv  Saved
# Get Data for :  BDSX
# D:/Python for Finance/Russell2000_Stocks/BDSX.csv  Saved
# Get Data for :  UIHC
# D:/Python for Finance/Russell2000_Stocks/UIHC.csv  Saved
# Get Data for :  FNCH
# D:/Python for Finance/Russell2000_Stocks/FNCH.csv  Saved
# Get Data for :  TLIS
# D:/Python for Finance/Russell2000_Stocks/TLIS.csv  Saved
# Get Data for :  DNAY
# D:/Python for Finance/Russell2000_Stocks/DNAY.csv  Saved
# Get Data for :  GMTX
# D:/Python for Finance/Russell2000_Stocks/GMTX.csv  Saved
# Get Data for :  OTRK
# D:/Python for Finance/Russell2000_Stocks/OTRK.csv  Saved
# Get Data for :  STON
# D:/Python for Finance/Russell2000_Stocks/STON.csv  Saved
# Get Data for :  SGTX
# D:/Python for Finance/Russell2000_Stocks/SGTX.csv  Saved
# Get Data for :  RGS
# D:/Python for Finance/Russell2000_Stocks/RGS.csv  Saved
# Get Data for :  REV
# D:/Python for Finance/Russell2000_Stocks/REV.csv  Saved
# Get Data for :  PRTG
# D:/Python for Finance/Russell2000_Stocks/PRTG.csv  Saved
# Get Data for :  TISI
# D:/Python for Finance/Russell2000_Stocks/TISI.csv  Saved
# Get Data for :  LABP
# D:/Python for Finance/Russell2000_Stocks/LABP.csv  Saved
# Get Data for :  AC
# D:/Python for Finance/Russell2000_Stocks/AC.csv  Saved
# Get Data for :  MIRM
# D:/Python for Finance/Russell2000_Stocks/MIRM.csv  Saved
# Get Data for :  VHI
# D:/Python for Finance/Russell2000_Stocks/VHI.csv  Saved
# Get Data for :  REPX
# D:/Python for Finance/Russell2000_Stocks/REPX.csv  Saved
# Get Data for :  HPK
# D:/Python for Finance/Russell2000_Stocks/HPK.csv  Saved
# Get Data for :  PRTH
# D:/Python for Finance/Russell2000_Stocks/PRTH.csv  Saved
# Get Data for :  NL
# D:/Python for Finance/Russell2000_Stocks/NL.csv  Saved
# Get Data for :  IMPL
# D:/Python for Finance/Russell2000_Stocks/IMPL.csv  Saved
# Get Data for :  SERA
# D:/Python for Finance/Russell2000_Stocks/SERA.csv  Saved
# Get Data for :  NH
# D:/Python for Finance/Russell2000_Stocks/NH.csv  Saved
# Get Data for :  SPRB
# D:/Python for Finance/Russell2000_Stocks/SPRB.csv  Saved
# Get Data for :  RPHM
# D:/Python for Finance/Russell2000_Stocks/RPHM.csv  Saved
# Get Data for :  CIX
# D:/Python for Finance/Russell2000_Stocks/CIX.csv  Saved
# Get Data for :  VALU
# D:/Python for Finance/Russell2000_Stocks/VALU.csv  Saved
# Get Data for :  ADRO
# - ADRO: No data found, symbol may be delisted
# D:/Python for Finance/Russell2000_Stocks/ADRO.csv  Saved
# Get Data for :  GNLN
# D:/Python for Finance/Russell2000_Stocks/GNLN.csv  Saved
# Get Data for :  WLLAW
# D:/Python for Finance/Russell2000_Stocks/WLLAW.csv  Saved
# Get Data for :  MDVL
# D:/Python for Finance/Russell2000_Stocks/MDVL.csv  Saved
# Get Data for :  FBRX
# D:/Python for Finance/Russell2000_Stocks/FBRX.csv  Saved
# Get Data for :  HMPT
# D:/Python for Finance/Russell2000_Stocks/HMPT.csv  Saved
# Get Data for :  DMS
# D:/Python for Finance/Russell2000_Stocks/DMS.csv  Saved
# Get Data for :  WLLBW
# D:/Python for Finance/Russell2000_Stocks/WLLBW.csv  Saved
# Get Data for :  GBL
# D:/Python for Finance/Russell2000_Stocks/GBL.csv  Saved
# Get Data for :  PDLI
# - PDLI: No data found, symbol may be delisted
# D:/Python for Finance/Russell2000_Stocks/PDLI.csv  Saved
# Get Data for :  GTXI
# - GTXI: No data found, symbol may be delisted
# D:/Python for Finance/Russell2000_Stocks/GTXI.csv  Saved
# Finished
# ['CRDA', 'ADRO', 'PDLI', 'GTXI']
